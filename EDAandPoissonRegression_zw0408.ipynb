# %%
## Import Python libraries


import pandas as pd



import numpy as np


import matplotlib.pyplot as plt


import seaborn as sns



from sklearn.compose import ColumnTransformer




from sklearn.pipeline import make_pipeline





from sklearn.preprocessing import(
    
    
    
    FunctionTransformer,
    
    

    
    StandardScaler
    
    
)




from sklearn.model_selection import train_test_split




from sklearn.pipeline import Pipeline



import xgboost as xgb


from xgboost import XGBRegressor 



from sklearn.metrics import mean_absolute_error



from sklearn.experimental import enable_hist_gradient_boosting 



from sklearn.ensemble import HistGradientBoostingRegressor


from sklearn.metrics import mean_squared_error



from sklearn.metrics import mean_absolute_error



from sklearn.metrics import mean_poisson_deviance



from scipy.special import factorial



from scipy.optimize import minimize
# Out:
# /Users/zhuoranwang/anaconda3/lib/python3.12/site-packages/sklearn/experimental/enable_hist_gradient_boosting.py:15: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.0.0-py3-none-macosx_12_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /Users/zhuoranwang/anaconda3/lib/python3.12/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in /Users/zhuoranwang/anaconda3/lib/python3.12/site-packages (from xgboost) (1.13.1)
# Downloading xgboost-3.0.0-py3-none-macosx_12_0_arm64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 718.3 kB/s eta 0:00:0000:0100:01
# Installing collected packages: xgboost
# Successfully installed xgboost-3.0.0

# %%
# Read data



data = pd.read_csv('/Users/zhuoranwang/Desktop/BootCamp_DS_2025/LungCancerData.csv')



data.head()
# Out:
#    ZCTA5     Zip_name  Population_18andOver  Pct_Civilian_Unemployed  \
# 0  20105  ZCTA5 20105                 13996                      2.3
# 1  20106  ZCTA5 20106                  4091                      4.6
# 2  20109  ZCTA5 20109                 29499                      4.5
# 3  20110  ZCTA5 20110                 36041                      5.6
# 4  20111  ZCTA5 20111                 26293                      5.6
#
#    Pct_BelowPoverty_18andOver  Pct_Population_Male_18andOver  \
# 0                    1.907688                      48.342384
# 1                   12.441946                      49.278905
# 2                    9.415209                      49.808468
# 3                    7.276174                      51.022447
# 4                    8.663903                      51.306431
#
#    Pct_Population_65andOver  Pct_Population_Male_65andOver  \
# 0                  9.024007                       4.801372
# 1                 26.766072                      13.664141
# 2                  8.959626                       3.328926
# 3                 12.299881                       5.479870
# 4                 11.569619                       5.480546
#
#    Pct_Population_Female_65andOver  Pct_Black_18andOver  ...  \
# 0                         4.222635            11.138897  ...
# 1                        13.101931             3.299927  ...
# 2                         5.630699            16.742940  ...
# 3                         6.820011            14.608363  ...
# 4                         6.089073             9.629940  ...
#
#    Pct_Hisp_65andOver  Pct_Hisp_Male_65andOver  Pct_Hisp_Female_65andOver  \
# 0            0.371535                 0.185767                   0.185767
# 1            0.000000                 0.000000                   0.000000
# 2            0.918675                 0.227126                   0.691549
# 3            1.048806                 0.413418                   0.635387
# 4            0.981250                 0.532461                   0.448789
#
#    BINGE_CrudePrev  CSMOKING_CrudePrev  OBESITY_CrudePrev  \
# 0             17.1                11.9               22.5
# 1             17.7                17.8               32.2
# 2             17.4                18.3               36.6
# 3             17.8                17.9               31.7
# 4             17.3                18.6               33.8
#
#    Median_Household_Income  ZCTA_pm2_5  sdi_score  case_n_18plus
# 0                 153314.0    7.801598        1.0           15.0
# 1                  82500.0    7.171176       18.0           21.0
# 2                  70629.0    7.940322       72.0           68.0
# 3                  81042.0    8.013779       50.0          102.0
# 4                  88207.0    8.080360       56.0           66.0
#
# [5 rows x 34 columns]

# %%
data.shape
# Out:
# (896, 34)

# %%
data.columns.tolist()
# Out:
# ['ZCTA5',
#  'Zip_name',
#  'Population_18andOver',
#  'Pct_Civilian_Unemployed',
#  'Pct_BelowPoverty_18andOver',
#  'Pct_Population_Male_18andOver',
#  'Pct_Population_65andOver',
#  'Pct_Population_Male_65andOver',
#  'Pct_Population_Female_65andOver',
#  'Pct_Black_18andOver',
#  'Pct_Black_Male_18andOver',
#  'Pct_Black_Female_18andOver',
#  'Pct_Black_65andOver',
#  'Pct_Black_Male_65andOver',
#  'Pct_Black_Female_65andOver',
#  'Pct_White_18andOver',
#  'Pct_White_Male_18andOver',
#  'Pct_White_Female_18andOver',
#  'Pct_White_65andOver',
#  'Pct_White_Male_65andOver',
#  'Pct_White_Female_65andOver',
#  'Pct_Hisp_18andOver',
#  'Pct_Hisp_Male_18andOver',
#  'Pct_Hisp_Female_18andOver',
#  'Pct_Hisp_65andOver',
#  'Pct_Hisp_Male_65andOver',
#  'Pct_Hisp_Female_65andOver',
#  'BINGE_CrudePrev',
#  'CSMOKING_CrudePrev',
#  'OBESITY_CrudePrev',
#  'Median_Household_Income',
#  'ZCTA_pm2_5',
#  'sdi_score',
#  'case_n_18plus']

# %%
data['ZCTA5']
# Out:
# 0      20105
# 1      20106
# 2      20109
# 3      20110
# 4      20111
#        ...
# 891    24646
# 892    24649
# 893    24651
# 894    24656
# 895    24657
# Name: ZCTA5, Length: 896, dtype: int64

# %%
data['ZCTA5'].dtype
# Out:
# dtype('int64')

# %%
# Remove Zipcodes having missing data

ZipCodes = np.array([22035, 22185, 22214, 23250, 24316, 23440])

# %%
subdata = data[~data['ZCTA5'].isin(ZipCodes)]

# %%
subdata.head()
# Out:
#    ZCTA5     Zip_name  Population_18andOver  Pct_Civilian_Unemployed  \
# 0  20105  ZCTA5 20105                 13996                      2.3
# 1  20106  ZCTA5 20106                  4091                      4.6
# 2  20109  ZCTA5 20109                 29499                      4.5
# 3  20110  ZCTA5 20110                 36041                      5.6
# 4  20111  ZCTA5 20111                 26293                      5.6
#
#    Pct_BelowPoverty_18andOver  Pct_Population_Male_18andOver  \
# 0                    1.907688                      48.342384
# 1                   12.441946                      49.278905
# 2                    9.415209                      49.808468
# 3                    7.276174                      51.022447
# 4                    8.663903                      51.306431
#
#    Pct_Population_65andOver  Pct_Population_Male_65andOver  \
# 0                  9.024007                       4.801372
# 1                 26.766072                      13.664141
# 2                  8.959626                       3.328926
# 3                 12.299881                       5.479870
# 4                 11.569619                       5.480546
#
#    Pct_Population_Female_65andOver  Pct_Black_18andOver  ...  \
# 0                         4.222635            11.138897  ...
# 1                        13.101931             3.299927  ...
# 2                         5.630699            16.742940  ...
# 3                         6.820011            14.608363  ...
# 4                         6.089073             9.629940  ...
#
#    Pct_Hisp_65andOver  Pct_Hisp_Male_65andOver  Pct_Hisp_Female_65andOver  \
# 0            0.371535                 0.185767                   0.185767
# 1            0.000000                 0.000000                   0.000000
# 2            0.918675                 0.227126                   0.691549
# 3            1.048806                 0.413418                   0.635387
# 4            0.981250                 0.532461                   0.448789
#
#    BINGE_CrudePrev  CSMOKING_CrudePrev  OBESITY_CrudePrev  \
# 0             17.1                11.9               22.5
# 1             17.7                17.8               32.2
# 2             17.4                18.3               36.6
# 3             17.8                17.9               31.7
# 4             17.3                18.6               33.8
#
#    Median_Household_Income  ZCTA_pm2_5  sdi_score  case_n_18plus
# 0                 153314.0    7.801598        1.0           15.0
# 1                  82500.0    7.171176       18.0           21.0
# 2                  70629.0    7.940322       72.0           68.0
# 3                  81042.0    8.013779       50.0          102.0
# 4                  88207.0    8.080360       56.0           66.0
#
# [5 rows x 34 columns]

# %%
subdata.shape
# Out:
# (890, 34)

# %%
subdata.dropna().shape[0]
# Out:
# 788

# %%
## Missing data in lung cancer cases among individuals aged 18 and above


subdata.shape[0] - subdata['case_n_18plus'].dropna().shape[0]
# Out:
# 62

# %%
## Missing data in lung cancer cases among individuals aged 18 and above



100 - (subdata['case_n_18plus'].dropna().shape[0]/subdata.shape[0])*100
# Out:
# 6.966292134831463

# %%
## Remove missing data


cleaneddata = subdata.dropna()

# %%
cleaneddata.shape
# Out:
# (788, 34)

# %%
cleaneddata['case_n_18plus'].mean()
# Out:
# 34.80329949238579

# %%
cleaneddata['case_n_18plus'].var()
# Out:
# 1782.8494427208634

# %%
cleaneddata['case_n_18plus'].std()
# Out:
# 42.22380185062524

# %%
# Since mean and variance are different, there is overdispersion in the data

# %%
plt.hist(cleaneddata['case_n_18plus'])
# Out:
# (array([450., 145.,  69.,  46.,  28.,  21.,  11.,   6.,   9.,   3.]),
#  array([  1. ,  24.3,  47.6,  70.9,  94.2, 117.5, 140.8, 164.1, 187.4,
#         210.7, 234. ]),
#  <BarContainer object of 10 artists>)

# %%
cleaneddata['case_n_18plus'].min()
# Out:
# 1.0

# %%
cleaneddata['case_n_18plus'].max()
# Out:
# 234.0

# %% [markdown]
# # Available features
#
# 1. Demographics: Gender (F, M), Race (Black, White, Other), Ethnicity (Hispanic or Latino;  Not Hispanic or Latino), Age (>= 65)
#
#
# 1.1. In particular: Percentage of males, Percentage of Blacks, Percentage of  Whites, Percentage of Hispanics
#
#
# The impact of race, specifically Black or White, on the prevalence of Lung cancer was measured against the  category ‘Other’, which includes Asian, Native Hawaiians and Other Pacific Islanders (NHPI), American Indian and Alaska Natives, some other race alone, and two or more races
#
#
#
# 1.2. The effect of age will be incorporated into the model through the variable: percentage of population with age ≥ 65
#
#
# 2. Prevalence of Binge Drinking, Smoking, and Obesity
#
#
# 3. Percent Population below Poverty
#
#
# 4. Social Deprivation Index (SDI)
#
#
# It quantify the socioeconomic variation in health outcomes
#
# It is a deprivation based on seven demographic characteristics
#
#
# The seven demographic characteristics:
#
#
# 4.1. Percent living in poverty,
#
# 4.2. Percent with less than 12 years of education
#
# 4.3. Percent single-parent households
#
# 4.4. Percent living in rented housing units
#
# 4.5. Percent living in overcrowded housing units
#
# 4.6. Percent of households without a car  and
#
# 4.7. Percent unemployed adults under 65 years of age
#
#
# Its value range from 1 to 100, with higher values reflecting greater deprivation
#
#
#
# 5. Average Daily Air Quality PM2.5 Concentration: Particulate Matter with a diameter of 2.5 micrometers or less

# %%
## Select features that we want to include in the modelling




variables = np.array(cleaneddata.columns.tolist())


variables
# Out:
# array(['ZCTA5', 'Zip_name', 'Population_18andOver',
#        'Pct_Civilian_Unemployed', 'Pct_BelowPoverty_18andOver',
#        'Pct_Population_Male_18andOver', 'Pct_Population_65andOver',
#        'Pct_Population_Male_65andOver', 'Pct_Population_Female_65andOver',
#        'Pct_Black_18andOver', 'Pct_Black_Male_18andOver',
#        'Pct_Black_Female_18andOver', 'Pct_Black_65andOver',
#        'Pct_Black_Male_65andOver', 'Pct_Black_Female_65andOver',
#        'Pct_White_18andOver', 'Pct_White_Male_18andOver',
#        'Pct_White_Female_18andOver', 'Pct_White_65andOver',
#        'Pct_White_Male_65andOver', 'Pct_White_Female_65andOver',
#        'Pct_Hisp_18andOver', 'Pct_Hisp_Male_18andOver',
#        'Pct_Hisp_Female_18andOver', 'Pct_Hisp_65andOver',
#        'Pct_Hisp_Male_65andOver', 'Pct_Hisp_Female_65andOver',
#        'BINGE_CrudePrev', 'CSMOKING_CrudePrev', 'OBESITY_CrudePrev',
#        'Median_Household_Income', 'ZCTA_pm2_5', 'sdi_score',
#        'case_n_18plus'], dtype='<U31')

# %%
removecolumns = np.array(['ZCTA5', 'Zip_name', 'case_n_18plus', 'Population_18andOver'])



removecolumns
# Out:
# array(['ZCTA5', 'Zip_name', 'case_n_18plus', 'Population_18andOver'],
#       dtype='<U20')

# %%
# Response variable


y = cleaneddata['case_n_18plus']


y
# Out:
# 0       15.0
# 1       21.0
# 2       68.0
# 3      102.0
# 4       66.0
#        ...
# 891      2.0
# 892     11.0
# 893     34.0
# 894     13.0
# 895      1.0
# Name: case_n_18plus, Length: 788, dtype: float64

# %%
N = cleaneddata['case_n_18plus']

# %% [markdown]
# ## Mathematical Formulation
#
#
# If we define the number of cases $Y_{i}$ in terms of the population $N_{i}$ with a given intensity $\lambda_{i}$,
# we assume that cases $Y_{i}$ arise as a Poisson process with rate $\lambda_{i}$, which represents the expected number of cases per individual in the population $N_{i}$
#
#
# Let
#
# * $Y_{i}$ be the total number of cases
# * $N_{i}$ be the total population
# * $\lambda_{i}$ be the intensity rate, defined as the expected number of cases per individual
#
#
#
#
#
# We assume that each individual independently experiences a case occurrence with rate $\lambda_{i}$
#
#
#
# Then, the total number of cases $Y_{i}$ follows a Poisson distribution:
#
#
#
# \begin{align}
#  Y_{i} \sim \text{Poisson}(\lambda_{i} N_{i})
# \end{align}
#
# This means that the probability of observing exactly $k$ cases is:
#
# \begin{align}
# P(Y_{i} = k) = \frac{(\lambda_{i} N_{i})^k e^{-\lambda_{i} N_{i}}}{k!}
# \end{align}
#
# where
# * $\lambda_{i} N_{i}$ is the expected number of cases in the population
# * $k!$ is the factorial of $k$

# %% [markdown]
# ## Mathematical Formulation
#
#
# If we define the number of cases $Y_{i}$ in terms of the population $N_{i}$ with a given intensity $\lambda_{i}$,
# we assume that cases $Y_{i}$ arise as a Poisson process with rate $\lambda_{i}$, which represents the expected number of cases per individual in the population $N_{i}$
#
#
# Let
#
# * $Y_{i}$ be the total number of cases
# * $N_{i}$ be the total population
# * $\lambda_{i}$ be the intensity rate, defined as the expected number of cases per individual
#
#
#
#
#
# We assume that each individual independently experiences a case occurrence with rate $\lambda_{i}$
#
#
#
# Then, the total number of cases $Y_{i}$ follows a Poisson distribution:
#
#
#
# \begin{align}
#  Y_{i} \sim \text{Poisson}(\lambda_{i} N_{i})
# \end{align}
#
# This means that the probability of observing exactly $k$ cases is:
#
# \begin{align}
# P(Y_{i} = k) = \frac{(\lambda_{i} N_{i})^k e^{-\lambda_{i} N_{i}}}{k!}
# \end{align}
#
# where
# * $\lambda_{i} N_{i}$ is the expected number of cases in the population
# * $k!$ is the factorial of $k$

# %% [markdown]
# ## Mathematical Formulation
#
#
# If we define the number of cases $Y_{i}$ in terms of the population $N_{i}$ with a given intensity $\lambda_{i}$,
# we assume that cases $Y_{i}$ arise as a Poisson process with rate $\lambda_{i}$, which represents the expected number of cases per individual in the population $N_{i}$
#
#
# Let
#
# * $Y_{i}$ be the total number of cases
# * $N_{i}$ be the total population
# * $\lambda_{i}$ be the intensity rate, defined as the expected number of cases per individual
#
#
#
#
#
# We assume that each individual independently experiences a case occurrence with rate $\lambda_{i}$
#
#
#
# Then, the total number of cases $Y_{i}$ follows a Poisson distribution:
#
#
#
# \begin{align}
#  Y_{i} \sim \text{Poisson}(\lambda_{i} N_{i})
# \end{align}
#
# This means that the probability of observing exactly $k$ cases is:
#
# \begin{align}
# P(Y_{i} = k) = \frac{(\lambda_{i} N_{i})^k e^{-\lambda_{i} N_{i}}}{k!}
# \end{align}
#
# where
# * $\lambda_{i} N_{i}$ is the expected number of cases in the population
# * $k!$ is the factorial of $k$

# %%
N = cleaneddata['Population_18andOver']



N
# Out:
# 0      13996
# 1       4091
# 2      29499
# 3      36041
# 4      26293
#        ...
# 891      710
# 892     2351
# 893     4316
# 894     2356
# 895      268
# Name: Population_18andOver, Length: 788, dtype: int64

# %%
## Features



xvariable = variables[~pd.Series(variables).isin(removecolumns)]


xvariable
# Out:
# array(['Pct_Civilian_Unemployed', 'Pct_BelowPoverty_18andOver',
#        'Pct_Population_Male_18andOver', 'Pct_Population_65andOver',
#        'Pct_Population_Male_65andOver', 'Pct_Population_Female_65andOver',
#        'Pct_Black_18andOver', 'Pct_Black_Male_18andOver',
#        'Pct_Black_Female_18andOver', 'Pct_Black_65andOver',
#        'Pct_Black_Male_65andOver', 'Pct_Black_Female_65andOver',
#        'Pct_White_18andOver', 'Pct_White_Male_18andOver',
#        'Pct_White_Female_18andOver', 'Pct_White_65andOver',
#        'Pct_White_Male_65andOver', 'Pct_White_Female_65andOver',
#        'Pct_Hisp_18andOver', 'Pct_Hisp_Male_18andOver',
#        'Pct_Hisp_Female_18andOver', 'Pct_Hisp_65andOver',
#        'Pct_Hisp_Male_65andOver', 'Pct_Hisp_Female_65andOver',
#        'BINGE_CrudePrev', 'CSMOKING_CrudePrev', 'OBESITY_CrudePrev',
#        'Median_Household_Income', 'ZCTA_pm2_5', 'sdi_score'], dtype='<U31')

# %%
xdata = cleaneddata[xvariable]


xdata
# Out:
#      Pct_Civilian_Unemployed  Pct_BelowPoverty_18andOver  \
# 0                        2.3                    1.907688
# 1                        4.6                   12.441946
# 2                        4.5                    9.415209
# 3                        5.6                    7.276174
# 4                        5.6                    8.663903
# ..                       ...                         ...
# 891                      5.9                   26.901408
# 892                      8.4                   20.799660
# 893                      6.7                   12.025316
# 894                      2.9                   23.047538
# 895                     12.8                   19.776119
#
#      Pct_Population_Male_18andOver  Pct_Population_65andOver  \
# 0                        48.342384                  9.024007
# 1                        49.278905                 26.766072
# 2                        49.808468                  8.959626
# 3                        51.022447                 12.299881
# 4                        51.306431                 11.569619
# ..                             ...                       ...
# 891                      54.366197                 19.154930
# 892                      50.999575                 13.100808
# 893                      49.606117                 26.459685
# 894                      53.098472                 29.668930
# 895                      47.014925                 14.925373
#
#      Pct_Population_Male_65andOver  Pct_Population_Female_65andOver  \
# 0                         4.801372                         4.222635
# 1                        13.664141                        13.101931
# 2                         3.328926                         5.630699
# 3                         5.479870                         6.820011
# 4                         5.480546                         6.089073
# ..                             ...                              ...
# 891                      11.267606                         7.887324
# 892                       7.230966                         5.869843
# 893                      11.329935                        15.129750
# 894                      13.412564                        16.256367
# 895                      11.194030                         3.731343
#
#      Pct_Black_18andOver  Pct_Black_Male_18andOver  \
# 0              11.138897                  5.244356
# 1               3.299927                  1.686629
# 2              16.742940                  7.993491
# 3              14.608363                  8.135179
# 4               9.629940                  5.339824
# ..                   ...                       ...
# 891             0.000000                  0.000000
# 892             0.000000                  0.000000
# 893             4.147359                  3.174235
# 894             0.000000                  0.000000
# 895             1.492537                  1.492537
#
#      Pct_Black_Female_18andOver  Pct_Black_65andOver  ...  \
# 0                      5.894541             0.685910  ...
# 1                      1.613297             0.562210  ...
# 2                      8.749449             1.247500  ...
# 3                      6.473183             1.459449  ...
# 4                      4.290115             1.361579  ...
# ..                          ...                  ...  ...
# 891                    0.000000             0.000000  ...
# 892                    0.000000             0.000000  ...
# 893                    0.973123             0.417053  ...
# 894                    0.000000             0.000000  ...
# 895                    0.000000             1.492537  ...
#
#      Pct_Hisp_Female_18andOver  Pct_Hisp_65andOver  Pct_Hisp_Male_65andOver  \
# 0                     3.958274            0.371535                 0.185767
# 1                     2.371058            0.000000                 0.000000
# 2                    16.841249            0.918675                 0.227126
# 3                    13.861991            1.048806                 0.413418
# 4                    14.600844            0.981250                 0.532461
# ..                         ...                 ...                      ...
# 891                   0.000000            0.000000                 0.000000
# 892                   0.000000            0.000000                 0.000000
# 893                   0.000000            0.000000                 0.000000
# 894                   0.000000            0.000000                 0.000000
# 895                   0.000000            0.000000                 0.000000
#
#      Pct_Hisp_Female_65andOver  BINGE_CrudePrev  CSMOKING_CrudePrev  \
# 0                     0.185767             17.1                11.9
# 1                     0.000000             17.7                17.8
# 2                     0.691549             17.4                18.3
# 3                     0.635387             17.8                17.9
# 4                     0.448789             17.3                18.6
# ..                         ...              ...                 ...
# 891                   0.000000             14.3                29.6
# 892                   0.000000             14.7                29.2
# 893                   0.000000             14.7                22.3
# 894                   0.000000             13.8                30.1
# 895                   0.000000             13.6                27.0
#
#      OBESITY_CrudePrev  Median_Household_Income  ZCTA_pm2_5  sdi_score
# 0                 22.5                 153314.0    7.801598        1.0
# 1                 32.2                  82500.0    7.171176       18.0
# 2                 36.6                  70629.0    7.940322       72.0
# 3                 31.7                  81042.0    8.013779       50.0
# 4                 33.8                  88207.0    8.080360       56.0
# ..                 ...                      ...         ...        ...
# 891               35.9                  25625.0    8.217162       60.0
# 892               36.7                  41318.0    8.007121       52.0
# 893               38.7                  47820.0    7.577166       54.0
# 894               36.6                  34668.0    8.219753       45.0
# 895               34.9                  38203.0    8.010354       57.0
#
# [788 rows x 30 columns]

# %%
corr_matrix = xdata.corr()




corr_matrix
# Out:
#                                  Pct_Civilian_Unemployed  \
# Pct_Civilian_Unemployed                         1.000000
# Pct_BelowPoverty_18andOver                      0.284317
# Pct_Population_Male_18andOver                  -0.007922
# Pct_Population_65andOver                       -0.077711
# Pct_Population_Male_65andOver                  -0.092958
# Pct_Population_Female_65andOver                -0.047935
# Pct_Black_18andOver                             0.162913
# Pct_Black_Male_18andOver                        0.156366
# Pct_Black_Female_18andOver                      0.155727
# Pct_Black_65andOver                             0.108836
# Pct_Black_Male_65andOver                        0.077249
# Pct_Black_Female_65andOver                      0.116550
# Pct_White_18andOver                            -0.124007
# Pct_White_Male_18andOver                       -0.113612
# Pct_White_Female_18andOver                     -0.110345
# Pct_White_65andOver                            -0.124932
# Pct_White_Male_65andOver                       -0.123681
# Pct_White_Female_65andOver                     -0.105454
# Pct_Hisp_18andOver                             -0.000730
# Pct_Hisp_Male_18andOver                         0.010300
# Pct_Hisp_Female_18andOver                      -0.012699
# Pct_Hisp_65andOver                             -0.052109
# Pct_Hisp_Male_65andOver                        -0.057263
# Pct_Hisp_Female_65andOver                      -0.033125
# BINGE_CrudePrev                                -0.061228
# CSMOKING_CrudePrev                              0.288750
# OBESITY_CrudePrev                               0.231296
# Median_Household_Income                        -0.251756
# ZCTA_pm2_5                                      0.117333
# sdi_score                                       0.420174
#
#                                  Pct_BelowPoverty_18andOver  \
# Pct_Civilian_Unemployed                            0.284317
# Pct_BelowPoverty_18andOver                         1.000000
# Pct_Population_Male_18andOver                      0.059129
# Pct_Population_65andOver                          -0.004378
# Pct_Population_Male_65andOver                     -0.035400
# Pct_Population_Female_65andOver                    0.023592
# Pct_Black_18andOver                                0.163803
# Pct_Black_Male_18andOver                           0.162618
# Pct_Black_Female_18andOver                         0.151827
# Pct_Black_65andOver                                0.120090
# Pct_Black_Male_65andOver                           0.083040
# Pct_Black_Female_65andOver                         0.130400
# Pct_White_18andOver                               -0.071408
# Pct_White_Male_18andOver                          -0.056379
# Pct_White_Female_18andOver                        -0.071836
# Pct_White_65andOver                               -0.038646
# Pct_White_Male_65andOver                          -0.056780
# Pct_White_Female_65andOver                        -0.016727
# Pct_Hisp_18andOver                                -0.127443
# Pct_Hisp_Male_18andOver                           -0.083492
# Pct_Hisp_Female_18andOver                         -0.160347
# Pct_Hisp_65andOver                                -0.178356
# Pct_Hisp_Male_65andOver                           -0.156583
# Pct_Hisp_Female_65andOver                         -0.142878
# BINGE_CrudePrev                                   -0.207701
# CSMOKING_CrudePrev                                 0.568748
# OBESITY_CrudePrev                                  0.417567
# Median_Household_Income                           -0.600622
# ZCTA_pm2_5                                         0.074323
# sdi_score                                          0.750921
#
#                                  Pct_Population_Male_18andOver  \
# Pct_Civilian_Unemployed                              -0.007922
# Pct_BelowPoverty_18andOver                            0.059129
# Pct_Population_Male_18andOver                         1.000000
# Pct_Population_65andOver                             -0.223480
# Pct_Population_Male_65andOver                        -0.011917
# Pct_Population_Female_65andOver                      -0.360478
# Pct_Black_18andOver                                  -0.018244
# Pct_Black_Male_18andOver                              0.175932
# Pct_Black_Female_18andOver                           -0.187700
# Pct_Black_65andOver                                  -0.097574
# Pct_Black_Male_65andOver                             -0.018311
# Pct_Black_Female_65andOver                           -0.146175
# Pct_White_18andOver                                  -0.021819
# Pct_White_Male_18andOver                              0.363197
# Pct_White_Female_18andOver                           -0.370869
# Pct_White_65andOver                                  -0.164756
# Pct_White_Male_65andOver                             -0.006092
# Pct_White_Female_65andOver                           -0.273813
# Pct_Hisp_18andOver                                    0.110243
# Pct_Hisp_Male_18andOver                               0.240479
# Pct_Hisp_Female_18andOver                            -0.045185
# Pct_Hisp_65andOver                                   -0.021373
# Pct_Hisp_Male_65andOver                              -0.021756
# Pct_Hisp_Female_65andOver                            -0.014882
# BINGE_CrudePrev                                       0.330378
# CSMOKING_CrudePrev                                    0.086707
# OBESITY_CrudePrev                                    -0.020899
# Median_Household_Income                              -0.011925
# ZCTA_pm2_5                                           -0.020952
# sdi_score                                             0.011337
#
#                                  Pct_Population_65andOver  \
# Pct_Civilian_Unemployed                         -0.077711
# Pct_BelowPoverty_18andOver                      -0.004378
# Pct_Population_Male_18andOver                   -0.223480
# Pct_Population_65andOver                         1.000000
# Pct_Population_Male_65andOver                    0.868894
# Pct_Population_Female_65andOver                  0.902128
# Pct_Black_18andOver                             -0.112705
# Pct_Black_Male_18andOver                        -0.135682
# Pct_Black_Female_18andOver                      -0.083524
# Pct_Black_65andOver                              0.191439
# Pct_Black_Male_65andOver                         0.166588
# Pct_Black_Female_65andOver                       0.179882
# Pct_White_18andOver                              0.286042
# Pct_White_Male_18andOver                         0.163440
# Pct_White_Female_18andOver                       0.344987
# Pct_White_65andOver                              0.876273
# Pct_White_Male_65andOver                         0.795820
# Pct_White_Female_65andOver                       0.801166
# Pct_Hisp_18andOver                              -0.429791
# Pct_Hisp_Male_18andOver                         -0.439339
# Pct_Hisp_Female_18andOver                       -0.368330
# Pct_Hisp_65andOver                              -0.162674
# Pct_Hisp_Male_65andOver                         -0.151515
# Pct_Hisp_Female_65andOver                       -0.123805
# BINGE_CrudePrev                                 -0.538285
# CSMOKING_CrudePrev                               0.159678
# OBESITY_CrudePrev                                0.206237
# Median_Household_Income                         -0.293114
# ZCTA_pm2_5                                      -0.262281
# sdi_score                                       -0.118890
#
#                                  Pct_Population_Male_65andOver  \
# Pct_Civilian_Unemployed                              -0.092958
# Pct_BelowPoverty_18andOver                           -0.035400
# Pct_Population_Male_18andOver                        -0.011917
# Pct_Population_65andOver                              0.868894
# Pct_Population_Male_65andOver                         1.000000
# Pct_Population_Female_65andOver                       0.570277
# Pct_Black_18andOver                                  -0.113260
# Pct_Black_Male_18andOver                             -0.102553
# Pct_Black_Female_18andOver                           -0.113681
# Pct_Black_65andOver                                   0.174959
# Pct_Black_Male_65andOver                              0.242698
# Pct_Black_Female_65andOver                            0.090389
# Pct_White_18andOver                                   0.268015
# Pct_White_Male_18andOver                              0.245608
# Pct_White_Female_18andOver                            0.238434
# Pct_White_65andOver                                   0.755400
# Pct_White_Male_65andOver                              0.881614
# Pct_White_Female_65andOver                            0.522824
# Pct_Hisp_18andOver                                   -0.394801
# Pct_Hisp_Male_18andOver                              -0.400882
# Pct_Hisp_Female_18andOver                            -0.341283
# Pct_Hisp_65andOver                                   -0.142334
# Pct_Hisp_Male_65andOver                              -0.127041
# Pct_Hisp_Female_65andOver                            -0.112462
# BINGE_CrudePrev                                      -0.448386
# CSMOKING_CrudePrev                                    0.132868
# OBESITY_CrudePrev                                     0.162476
# Median_Household_Income                              -0.221699
# ZCTA_pm2_5                                           -0.264049
# sdi_score                                            -0.152033
#
#                                  Pct_Population_Female_65andOver  \
# Pct_Civilian_Unemployed                                -0.047935
# Pct_BelowPoverty_18andOver                              0.023592
# Pct_Population_Male_18andOver                          -0.360478
# Pct_Population_65andOver                                0.902128
# Pct_Population_Male_65andOver                           0.570277
# Pct_Population_Female_65andOver                         1.000000
# Pct_Black_18andOver                                    -0.088311
# Pct_Black_Male_18andOver                               -0.135774
# Pct_Black_Female_18andOver                             -0.039518
# Pct_Black_65andOver                                     0.165189
# Pct_Black_Male_65andOver                                0.064905
# Pct_Black_Female_65andOver                              0.219726
# Pct_White_18andOver                                     0.241072
# Pct_White_Male_18andOver                                0.057144
# Pct_White_Female_18andOver                              0.364675
# Pct_White_65andOver                                     0.795730
# Pct_White_Male_65andOver                                0.552203
# Pct_White_Female_65andOver                              0.873817
# Pct_Hisp_18andOver                                     -0.369109
# Pct_Hisp_Male_18andOver                                -0.379653
# Pct_Hisp_Female_18andOver                              -0.313764
# Pct_Hisp_65andOver                                     -0.145893
# Pct_Hisp_Male_65andOver                                -0.140703
# Pct_Hisp_Female_65andOver                              -0.107426
# BINGE_CrudePrev                                        -0.502448
# CSMOKING_CrudePrev                                      0.149171
# OBESITY_CrudePrev                                       0.200628
# Median_Household_Income                                -0.293179
# ZCTA_pm2_5                                             -0.205097
# sdi_score                                              -0.064778
#
#                                  Pct_Black_18andOver  \
# Pct_Civilian_Unemployed                     0.162913
# Pct_BelowPoverty_18andOver                  0.163803
# Pct_Population_Male_18andOver              -0.018244
# Pct_Population_65andOver                   -0.112705
# Pct_Population_Male_65andOver              -0.113260
# Pct_Population_Female_65andOver            -0.088311
# Pct_Black_18andOver                         1.000000
# Pct_Black_Male_18andOver                    0.951843
# Pct_Black_Female_18andOver                  0.962904
# Pct_Black_65andOver                         0.798901
# Pct_Black_Male_65andOver                    0.701649
# Pct_Black_Female_65andOver                  0.745395
# Pct_White_18andOver                        -0.914274
# Pct_White_Male_18andOver                   -0.822129
# Pct_White_Female_18andOver                 -0.827771
# Pct_White_65andOver                        -0.492557
# Pct_White_Male_65andOver                   -0.449692
# Pct_White_Female_65andOver                 -0.448316
# Pct_Hisp_18andOver                          0.054080
# Pct_Hisp_Male_18andOver                     0.079443
# Pct_Hisp_Female_18andOver                   0.019940
# Pct_Hisp_65andOver                         -0.047083
# Pct_Hisp_Male_65andOver                    -0.032335
# Pct_Hisp_Female_65andOver                  -0.044454
# BINGE_CrudePrev                            -0.212795
# CSMOKING_CrudePrev                          0.161715
# OBESITY_CrudePrev                           0.466952
# Median_Household_Income                    -0.203876
# ZCTA_pm2_5                                  0.042459
# sdi_score                                   0.394691
#
#                                  Pct_Black_Male_18andOver  \
# Pct_Civilian_Unemployed                          0.156366
# Pct_BelowPoverty_18andOver                       0.162618
# Pct_Population_Male_18andOver                    0.175932
# Pct_Population_65andOver                        -0.135682
# Pct_Population_Male_65andOver                   -0.102553
# Pct_Population_Female_65andOver                 -0.135774
# Pct_Black_18andOver                              0.951843
# Pct_Black_Male_18andOver                         1.000000
# Pct_Black_Female_18andOver                       0.833802
# Pct_Black_65andOver                              0.730725
# Pct_Black_Male_65andOver                         0.690816
# Pct_Black_Female_65andOver                       0.641656
# Pct_White_18andOver                             -0.873426
# Pct_White_Male_18andOver                        -0.755940
# Pct_White_Female_18andOver                      -0.817806
# Pct_White_65andOver                             -0.479770
# Pct_White_Male_65andOver                        -0.431920
# Pct_White_Female_65andOver                      -0.441911
# Pct_Hisp_18andOver                               0.082967
# Pct_Hisp_Male_18andOver                          0.127105
# Pct_Hisp_Female_18andOver                        0.024878
# Pct_Hisp_65andOver                              -0.039095
# Pct_Hisp_Male_65andOver                         -0.030975
# Pct_Hisp_Female_65andOver                       -0.033824
# BINGE_CrudePrev                                 -0.152152
# CSMOKING_CrudePrev                               0.176389
# OBESITY_CrudePrev                                0.444237
# Median_Household_Income                         -0.199528
# ZCTA_pm2_5                                       0.038886
# sdi_score                                        0.376491
#
#                                  Pct_Black_Female_18andOver  \
# Pct_Civilian_Unemployed                            0.155727
# Pct_BelowPoverty_18andOver                         0.151827
# Pct_Population_Male_18andOver                     -0.187700
# Pct_Population_65andOver                          -0.083524
# Pct_Population_Male_65andOver                     -0.113681
# Pct_Population_Female_65andOver                   -0.039518
# Pct_Black_18andOver                                0.962904
# Pct_Black_Male_18andOver                           0.833802
# Pct_Black_Female_18andOver                         1.000000
# Pct_Black_65andOver                                0.795408
# Pct_Black_Male_65andOver                           0.655415
# Pct_Black_Female_65andOver                         0.777455
# Pct_White_18andOver                               -0.877558
# Pct_White_Male_18andOver                          -0.815040
# Pct_White_Female_18andOver                        -0.770749
# Pct_White_65andOver                               -0.464662
# Pct_White_Male_65andOver                          -0.429592
# Pct_White_Female_65andOver                        -0.418321
# Pct_Hisp_18andOver                                 0.024356
# Pct_Hisp_Male_18andOver                            0.031179
# Pct_Hisp_Female_18andOver                          0.014008
# Pct_Hisp_65andOver                                -0.050371
# Pct_Hisp_Male_65andOver                           -0.030963
# Pct_Hisp_Female_65andOver                         -0.050277
# BINGE_CrudePrev                                   -0.249257
# CSMOKING_CrudePrev                                 0.135946
# OBESITY_CrudePrev                                  0.449830
# Median_Household_Income                           -0.191498
# ZCTA_pm2_5                                         0.042230
# sdi_score                                          0.379338
#
#                                  Pct_Black_65andOver  ...  \
# Pct_Civilian_Unemployed                     0.108836  ...
# Pct_BelowPoverty_18andOver                  0.120090  ...
# Pct_Population_Male_18andOver              -0.097574  ...
# Pct_Population_65andOver                    0.191439  ...
# Pct_Population_Male_65andOver               0.174959  ...
# Pct_Population_Female_65andOver             0.165189  ...
# Pct_Black_18andOver                         0.798901  ...
# Pct_Black_Male_18andOver                    0.730725  ...
# Pct_Black_Female_18andOver                  0.795408  ...
# Pct_Black_65andOver                         1.000000  ...
# Pct_Black_Male_65andOver                    0.887003  ...
# Pct_Black_Female_65andOver                  0.925878  ...
# Pct_White_18andOver                        -0.677418  ...
# Pct_White_Male_18andOver                   -0.628600  ...
# Pct_White_Female_18andOver                 -0.595481  ...
# Pct_White_65andOver                        -0.292318  ...
# Pct_White_Male_65andOver                   -0.244070  ...
# Pct_White_Female_65andOver                 -0.285636  ...
# Pct_Hisp_18andOver                         -0.108176  ...
# Pct_Hisp_Male_18andOver                    -0.091428  ...
# Pct_Hisp_Female_18andOver                  -0.113638  ...
# Pct_Hisp_65andOver                         -0.110097  ...
# Pct_Hisp_Male_65andOver                    -0.091130  ...
# Pct_Hisp_Female_65andOver                  -0.092335  ...
# BINGE_CrudePrev                            -0.339376  ...
# CSMOKING_CrudePrev                          0.161396  ...
# OBESITY_CrudePrev                           0.436318  ...
# Median_Household_Income                    -0.214677  ...
# ZCTA_pm2_5                                 -0.008193  ...
# sdi_score                                   0.234387  ...
#
#                                  Pct_Hisp_Female_18andOver  \
# Pct_Civilian_Unemployed                          -0.012699
# Pct_BelowPoverty_18andOver                       -0.160347
# Pct_Population_Male_18andOver                    -0.045185
# Pct_Population_65andOver                         -0.368330
# Pct_Population_Male_65andOver                    -0.341283
# Pct_Population_Female_65andOver                  -0.313764
# Pct_Black_18andOver                               0.019940
# Pct_Black_Male_18andOver                          0.024878
# Pct_Black_Female_18andOver                        0.014008
# Pct_Black_65andOver                              -0.113638
# Pct_Black_Male_65andOver                         -0.104644
# Pct_Black_Female_65andOver                       -0.102068
# Pct_White_18andOver                              -0.263101
# Pct_White_Male_18andOver                         -0.258753
# Pct_White_Female_18andOver                       -0.217874
# Pct_White_65andOver                              -0.336773
# Pct_White_Male_65andOver                         -0.320577
# Pct_White_Female_65andOver                       -0.295272
# Pct_Hisp_18andOver                                0.937846
# Pct_Hisp_Male_18andOver                           0.779102
# Pct_Hisp_Female_18andOver                         1.000000
# Pct_Hisp_65andOver                                0.512642
# Pct_Hisp_Male_65andOver                           0.369577
# Pct_Hisp_Female_65andOver                         0.470914
# BINGE_CrudePrev                                   0.233697
# CSMOKING_CrudePrev                               -0.378109
# OBESITY_CrudePrev                                -0.331801
# Median_Household_Income                           0.358818
# ZCTA_pm2_5                                        0.250778
# sdi_score                                         0.046764
#
#                                  Pct_Hisp_65andOver  Pct_Hisp_Male_65andOver  \
# Pct_Civilian_Unemployed                   -0.052109                -0.057263
# Pct_BelowPoverty_18andOver                -0.178356                -0.156583
# Pct_Population_Male_18andOver             -0.021373                -0.021756
# Pct_Population_65andOver                  -0.162674                -0.151515
# Pct_Population_Male_65andOver             -0.142334                -0.127041
# Pct_Population_Female_65andOver           -0.145893                -0.140703
# Pct_Black_18andOver                       -0.047083                -0.032335
# Pct_Black_Male_18andOver                  -0.039095                -0.030975
# Pct_Black_Female_18andOver                -0.050371                -0.030963
# Pct_Black_65andOver                       -0.110097                -0.091130
# Pct_Black_Male_65andOver                  -0.086314                -0.085918
# Pct_Black_Female_65andOver                -0.111218                -0.080214
# Pct_White_18andOver                       -0.134178                -0.110533
# Pct_White_Male_18andOver                  -0.135879                -0.110544
# Pct_White_Female_18andOver                -0.107519                -0.089847
# Pct_White_65andOver                       -0.143014                -0.134514
# Pct_White_Male_65andOver                  -0.132010                -0.112103
# Pct_White_Female_65andOver                -0.128932                -0.131618
# Pct_Hisp_18andOver                         0.505972                 0.404206
# Pct_Hisp_Male_18andOver                    0.444908                 0.391983
# Pct_Hisp_Female_18andOver                  0.512642                 0.369577
# Pct_Hisp_65andOver                         1.000000                 0.772652
# Pct_Hisp_Male_65andOver                    0.772652                 1.000000
# Pct_Hisp_Female_65andOver                  0.879884                 0.378180
# BINGE_CrudePrev                            0.107604                 0.084739
# CSMOKING_CrudePrev                        -0.408523                -0.308936
# OBESITY_CrudePrev                         -0.385662                -0.280382
# Median_Household_Income                    0.397732                 0.321707
# ZCTA_pm2_5                                 0.281344                 0.204952
# sdi_score                                 -0.056250                -0.040207
#
#                                  Pct_Hisp_Female_65andOver  BINGE_CrudePrev  \
# Pct_Civilian_Unemployed                          -0.033125        -0.061228
# Pct_BelowPoverty_18andOver                       -0.142878        -0.207701
# Pct_Population_Male_18andOver                    -0.014882         0.330378
# Pct_Population_65andOver                         -0.123805        -0.538285
# Pct_Population_Male_65andOver                    -0.112462        -0.448386
# Pct_Population_Female_65andOver                  -0.107426        -0.502448
# Pct_Black_18andOver                              -0.044454        -0.212795
# Pct_Black_Male_18andOver                         -0.033824        -0.152152
# Pct_Black_Female_18andOver                       -0.050277        -0.249257
# Pct_Black_65andOver                              -0.092335        -0.339376
# Pct_Black_Male_65andOver                         -0.061554        -0.280406
# Pct_Black_Female_65andOver                       -0.102139        -0.331094
# Pct_White_18andOver                              -0.112926         0.090612
# Pct_White_Male_18andOver                         -0.115398         0.226090
# Pct_White_Female_18andOver                       -0.089535        -0.050596
# Pct_White_65andOver                              -0.107861        -0.354423
# Pct_White_Male_65andOver                         -0.108590        -0.309522
# Pct_White_Female_65andOver                       -0.089493        -0.334652
# Pct_Hisp_18andOver                                0.435267         0.314291
# Pct_Hisp_Male_18andOver                           0.355371         0.353893
# Pct_Hisp_Female_18andOver                         0.470914         0.233697
# Pct_Hisp_65andOver                                0.879884         0.107604
# Pct_Hisp_Male_65andOver                           0.378180         0.084739
# Pct_Hisp_Female_65andOver                         1.000000         0.093482
# BINGE_CrudePrev                                   0.093482         1.000000
# CSMOKING_CrudePrev                               -0.364476        -0.336059
# OBESITY_CrudePrev                                -0.352512        -0.471289
# Median_Household_Income                           0.339180         0.310203
# ZCTA_pm2_5                                        0.256853         0.090237
# sdi_score                                        -0.051929        -0.166502
#
#                                  CSMOKING_CrudePrev  OBESITY_CrudePrev  \
# Pct_Civilian_Unemployed                    0.288750           0.231296
# Pct_BelowPoverty_18andOver                 0.568748           0.417567
# Pct_Population_Male_18andOver              0.086707          -0.020899
# Pct_Population_65andOver                   0.159678           0.206237
# Pct_Population_Male_65andOver              0.132868           0.162476
# Pct_Population_Female_65andOver            0.149171           0.200628
# Pct_Black_18andOver                        0.161715           0.466952
# Pct_Black_Male_18andOver                   0.176389           0.444237
# Pct_Black_Female_18andOver                 0.135946           0.449830
# Pct_Black_65andOver                        0.161396           0.436318
# Pct_Black_Male_65andOver                   0.134796           0.358363
# Pct_Black_Female_65andOver                 0.156276           0.427422
# Pct_White_18andOver                        0.069719          -0.211126
# Pct_White_Male_18andOver                   0.086864          -0.205144
# Pct_White_Female_18andOver                 0.040953          -0.177121
# Pct_White_65andOver                        0.120081           0.027367
# Pct_White_Male_65andOver                   0.104281           0.021896
# Pct_White_Female_65andOver                 0.113886           0.027559
# Pct_Hisp_18andOver                        -0.356670          -0.324137
# Pct_Hisp_Male_18andOver                   -0.298310          -0.281915
# Pct_Hisp_Female_18andOver                 -0.378109          -0.331801
# Pct_Hisp_65andOver                        -0.408523          -0.385662
# Pct_Hisp_Male_65andOver                   -0.308936          -0.280382
# Pct_Hisp_Female_65andOver                 -0.364476          -0.352512
# BINGE_CrudePrev                           -0.336059          -0.471289
# CSMOKING_CrudePrev                         1.000000           0.809360
# OBESITY_CrudePrev                          0.809360           1.000000
# Median_Household_Income                   -0.805534          -0.707811
# ZCTA_pm2_5                                -0.115975          -0.264881
# sdi_score                                  0.555025           0.470357
#
#                                  Median_Household_Income  ZCTA_pm2_5  \
# Pct_Civilian_Unemployed                        -0.251756    0.117333
# Pct_BelowPoverty_18andOver                     -0.600622    0.074323
# Pct_Population_Male_18andOver                  -0.011925   -0.020952
# Pct_Population_65andOver                       -0.293114   -0.262281
# Pct_Population_Male_65andOver                  -0.221699   -0.264049
# Pct_Population_Female_65andOver                -0.293179   -0.205097
# Pct_Black_18andOver                            -0.203876    0.042459
# Pct_Black_Male_18andOver                       -0.199528    0.038886
# Pct_Black_Female_18andOver                     -0.191498    0.042230
# Pct_Black_65andOver                            -0.214677   -0.008193
# Pct_Black_Male_65andOver                       -0.179466   -0.011871
# Pct_Black_Female_65andOver                     -0.207726   -0.003819
# Pct_White_18andOver                            -0.037154   -0.183719
# Pct_White_Male_18andOver                       -0.027610   -0.175087
# Pct_White_Female_18andOver                     -0.038957   -0.157271
# Pct_White_65andOver                            -0.226271   -0.273462
# Pct_White_Male_65andOver                       -0.174236   -0.279305
# Pct_White_Female_65andOver                     -0.233704   -0.223464
# Pct_Hisp_18andOver                              0.336608    0.259960
# Pct_Hisp_Male_18andOver                         0.279722    0.240122
# Pct_Hisp_Female_18andOver                       0.358818    0.250778
# Pct_Hisp_65andOver                              0.397732    0.281344
# Pct_Hisp_Male_65andOver                         0.321707    0.204952
# Pct_Hisp_Female_65andOver                       0.339180    0.256853
# BINGE_CrudePrev                                 0.310203    0.090237
# CSMOKING_CrudePrev                             -0.805534   -0.115975
# OBESITY_CrudePrev                              -0.707811   -0.264881
# Median_Household_Income                         1.000000    0.243723
# ZCTA_pm2_5                                      0.243723    1.000000
# sdi_score                                      -0.617704    0.127270
#
#                                  sdi_score
# Pct_Civilian_Unemployed           0.420174
# Pct_BelowPoverty_18andOver        0.750921
# Pct_Population_Male_18andOver     0.011337
# Pct_Population_65andOver         -0.118890
# Pct_Population_Male_65andOver    -0.152033
# Pct_Population_Female_65andOver  -0.064778
# Pct_Black_18andOver               0.394691
# Pct_Black_Male_18andOver          0.376491
# Pct_Black_Female_18andOver        0.379338
# Pct_Black_65andOver               0.234387
# Pct_Black_Male_65andOver          0.177798
# Pct_Black_Female_65andOver        0.241646
# Pct_White_18andOver              -0.323748
# Pct_White_Male_18andOver         -0.288539
# Pct_White_Female_18andOver       -0.295484
# Pct_White_65andOver              -0.212340
# Pct_White_Male_65andOver         -0.225845
# Pct_White_Female_65andOver       -0.165821
# Pct_Hisp_18andOver                0.097995
# Pct_Hisp_Male_18andOver           0.134224
# Pct_Hisp_Female_18andOver         0.046764
# Pct_Hisp_65andOver               -0.056250
# Pct_Hisp_Male_65andOver          -0.040207
# Pct_Hisp_Female_65andOver        -0.051929
# BINGE_CrudePrev                  -0.166502
# CSMOKING_CrudePrev                0.555025
# OBESITY_CrudePrev                 0.470357
# Median_Household_Income          -0.617704
# ZCTA_pm2_5                        0.127270
# sdi_score                         1.000000
#
# [30 rows x 30 columns]

# %%
corr_matrix.shape
# Out:
# (30, 30)

# %%
plt.figure(figsize = (16,15))



# Create a heatmap


sns.heatmap(corr_matrix,   cmap = 'coolwarm')



# Show the plot



plt.show()

# %%
corrdata = corr_matrix[corr_matrix>=0.75]


corrdata
# Out:
#                                  Pct_Civilian_Unemployed  \
# Pct_Civilian_Unemployed                              1.0
# Pct_BelowPoverty_18andOver                           NaN
# Pct_Population_Male_18andOver                        NaN
# Pct_Population_65andOver                             NaN
# Pct_Population_Male_65andOver                        NaN
# Pct_Population_Female_65andOver                      NaN
# Pct_Black_18andOver                                  NaN
# Pct_Black_Male_18andOver                             NaN
# Pct_Black_Female_18andOver                           NaN
# Pct_Black_65andOver                                  NaN
# Pct_Black_Male_65andOver                             NaN
# Pct_Black_Female_65andOver                           NaN
# Pct_White_18andOver                                  NaN
# Pct_White_Male_18andOver                             NaN
# Pct_White_Female_18andOver                           NaN
# Pct_White_65andOver                                  NaN
# Pct_White_Male_65andOver                             NaN
# Pct_White_Female_65andOver                           NaN
# Pct_Hisp_18andOver                                   NaN
# Pct_Hisp_Male_18andOver                              NaN
# Pct_Hisp_Female_18andOver                            NaN
# Pct_Hisp_65andOver                                   NaN
# Pct_Hisp_Male_65andOver                              NaN
# Pct_Hisp_Female_65andOver                            NaN
# BINGE_CrudePrev                                      NaN
# CSMOKING_CrudePrev                                   NaN
# OBESITY_CrudePrev                                    NaN
# Median_Household_Income                              NaN
# ZCTA_pm2_5                                           NaN
# sdi_score                                            NaN
#
#                                  Pct_BelowPoverty_18andOver  \
# Pct_Civilian_Unemployed                                 NaN
# Pct_BelowPoverty_18andOver                         1.000000
# Pct_Population_Male_18andOver                           NaN
# Pct_Population_65andOver                                NaN
# Pct_Population_Male_65andOver                           NaN
# Pct_Population_Female_65andOver                         NaN
# Pct_Black_18andOver                                     NaN
# Pct_Black_Male_18andOver                                NaN
# Pct_Black_Female_18andOver                              NaN
# Pct_Black_65andOver                                     NaN
# Pct_Black_Male_65andOver                                NaN
# Pct_Black_Female_65andOver                              NaN
# Pct_White_18andOver                                     NaN
# Pct_White_Male_18andOver                                NaN
# Pct_White_Female_18andOver                              NaN
# Pct_White_65andOver                                     NaN
# Pct_White_Male_65andOver                                NaN
# Pct_White_Female_65andOver                              NaN
# Pct_Hisp_18andOver                                      NaN
# Pct_Hisp_Male_18andOver                                 NaN
# Pct_Hisp_Female_18andOver                               NaN
# Pct_Hisp_65andOver                                      NaN
# Pct_Hisp_Male_65andOver                                 NaN
# Pct_Hisp_Female_65andOver                               NaN
# BINGE_CrudePrev                                         NaN
# CSMOKING_CrudePrev                                      NaN
# OBESITY_CrudePrev                                       NaN
# Median_Household_Income                                 NaN
# ZCTA_pm2_5                                              NaN
# sdi_score                                          0.750921
#
#                                  Pct_Population_Male_18andOver  \
# Pct_Civilian_Unemployed                                    NaN
# Pct_BelowPoverty_18andOver                                 NaN
# Pct_Population_Male_18andOver                              1.0
# Pct_Population_65andOver                                   NaN
# Pct_Population_Male_65andOver                              NaN
# Pct_Population_Female_65andOver                            NaN
# Pct_Black_18andOver                                        NaN
# Pct_Black_Male_18andOver                                   NaN
# Pct_Black_Female_18andOver                                 NaN
# Pct_Black_65andOver                                        NaN
# Pct_Black_Male_65andOver                                   NaN
# Pct_Black_Female_65andOver                                 NaN
# Pct_White_18andOver                                        NaN
# Pct_White_Male_18andOver                                   NaN
# Pct_White_Female_18andOver                                 NaN
# Pct_White_65andOver                                        NaN
# Pct_White_Male_65andOver                                   NaN
# Pct_White_Female_65andOver                                 NaN
# Pct_Hisp_18andOver                                         NaN
# Pct_Hisp_Male_18andOver                                    NaN
# Pct_Hisp_Female_18andOver                                  NaN
# Pct_Hisp_65andOver                                         NaN
# Pct_Hisp_Male_65andOver                                    NaN
# Pct_Hisp_Female_65andOver                                  NaN
# BINGE_CrudePrev                                            NaN
# CSMOKING_CrudePrev                                         NaN
# OBESITY_CrudePrev                                          NaN
# Median_Household_Income                                    NaN
# ZCTA_pm2_5                                                 NaN
# sdi_score                                                  NaN
#
#                                  Pct_Population_65andOver  \
# Pct_Civilian_Unemployed                               NaN
# Pct_BelowPoverty_18andOver                            NaN
# Pct_Population_Male_18andOver                         NaN
# Pct_Population_65andOver                         1.000000
# Pct_Population_Male_65andOver                    0.868894
# Pct_Population_Female_65andOver                  0.902128
# Pct_Black_18andOver                                   NaN
# Pct_Black_Male_18andOver                              NaN
# Pct_Black_Female_18andOver                            NaN
# Pct_Black_65andOver                                   NaN
# Pct_Black_Male_65andOver                              NaN
# Pct_Black_Female_65andOver                            NaN
# Pct_White_18andOver                                   NaN
# Pct_White_Male_18andOver                              NaN
# Pct_White_Female_18andOver                            NaN
# Pct_White_65andOver                              0.876273
# Pct_White_Male_65andOver                         0.795820
# Pct_White_Female_65andOver                       0.801166
# Pct_Hisp_18andOver                                    NaN
# Pct_Hisp_Male_18andOver                               NaN
# Pct_Hisp_Female_18andOver                             NaN
# Pct_Hisp_65andOver                                    NaN
# Pct_Hisp_Male_65andOver                               NaN
# Pct_Hisp_Female_65andOver                             NaN
# BINGE_CrudePrev                                       NaN
# CSMOKING_CrudePrev                                    NaN
# OBESITY_CrudePrev                                     NaN
# Median_Household_Income                               NaN
# ZCTA_pm2_5                                            NaN
# sdi_score                                             NaN
#
#                                  Pct_Population_Male_65andOver  \
# Pct_Civilian_Unemployed                                    NaN
# Pct_BelowPoverty_18andOver                                 NaN
# Pct_Population_Male_18andOver                              NaN
# Pct_Population_65andOver                              0.868894
# Pct_Population_Male_65andOver                         1.000000
# Pct_Population_Female_65andOver                            NaN
# Pct_Black_18andOver                                        NaN
# Pct_Black_Male_18andOver                                   NaN
# Pct_Black_Female_18andOver                                 NaN
# Pct_Black_65andOver                                        NaN
# Pct_Black_Male_65andOver                                   NaN
# Pct_Black_Female_65andOver                                 NaN
# Pct_White_18andOver                                        NaN
# Pct_White_Male_18andOver                                   NaN
# Pct_White_Female_18andOver                                 NaN
# Pct_White_65andOver                                   0.755400
# Pct_White_Male_65andOver                              0.881614
# Pct_White_Female_65andOver                                 NaN
# Pct_Hisp_18andOver                                         NaN
# Pct_Hisp_Male_18andOver                                    NaN
# Pct_Hisp_Female_18andOver                                  NaN
# Pct_Hisp_65andOver                                         NaN
# Pct_Hisp_Male_65andOver                                    NaN
# Pct_Hisp_Female_65andOver                                  NaN
# BINGE_CrudePrev                                            NaN
# CSMOKING_CrudePrev                                         NaN
# OBESITY_CrudePrev                                          NaN
# Median_Household_Income                                    NaN
# ZCTA_pm2_5                                                 NaN
# sdi_score                                                  NaN
#
#                                  Pct_Population_Female_65andOver  \
# Pct_Civilian_Unemployed                                      NaN
# Pct_BelowPoverty_18andOver                                   NaN
# Pct_Population_Male_18andOver                                NaN
# Pct_Population_65andOver                                0.902128
# Pct_Population_Male_65andOver                                NaN
# Pct_Population_Female_65andOver                         1.000000
# Pct_Black_18andOver                                          NaN
# Pct_Black_Male_18andOver                                     NaN
# Pct_Black_Female_18andOver                                   NaN
# Pct_Black_65andOver                                          NaN
# Pct_Black_Male_65andOver                                     NaN
# Pct_Black_Female_65andOver                                   NaN
# Pct_White_18andOver                                          NaN
# Pct_White_Male_18andOver                                     NaN
# Pct_White_Female_18andOver                                   NaN
# Pct_White_65andOver                                     0.795730
# Pct_White_Male_65andOver                                     NaN
# Pct_White_Female_65andOver                              0.873817
# Pct_Hisp_18andOver                                           NaN
# Pct_Hisp_Male_18andOver                                      NaN
# Pct_Hisp_Female_18andOver                                    NaN
# Pct_Hisp_65andOver                                           NaN
# Pct_Hisp_Male_65andOver                                      NaN
# Pct_Hisp_Female_65andOver                                    NaN
# BINGE_CrudePrev                                              NaN
# CSMOKING_CrudePrev                                           NaN
# OBESITY_CrudePrev                                            NaN
# Median_Household_Income                                      NaN
# ZCTA_pm2_5                                                   NaN
# sdi_score                                                    NaN
#
#                                  Pct_Black_18andOver  \
# Pct_Civilian_Unemployed                          NaN
# Pct_BelowPoverty_18andOver                       NaN
# Pct_Population_Male_18andOver                    NaN
# Pct_Population_65andOver                         NaN
# Pct_Population_Male_65andOver                    NaN
# Pct_Population_Female_65andOver                  NaN
# Pct_Black_18andOver                         1.000000
# Pct_Black_Male_18andOver                    0.951843
# Pct_Black_Female_18andOver                  0.962904
# Pct_Black_65andOver                         0.798901
# Pct_Black_Male_65andOver                         NaN
# Pct_Black_Female_65andOver                       NaN
# Pct_White_18andOver                              NaN
# Pct_White_Male_18andOver                         NaN
# Pct_White_Female_18andOver                       NaN
# Pct_White_65andOver                              NaN
# Pct_White_Male_65andOver                         NaN
# Pct_White_Female_65andOver                       NaN
# Pct_Hisp_18andOver                               NaN
# Pct_Hisp_Male_18andOver                          NaN
# Pct_Hisp_Female_18andOver                        NaN
# Pct_Hisp_65andOver                               NaN
# Pct_Hisp_Male_65andOver                          NaN
# Pct_Hisp_Female_65andOver                        NaN
# BINGE_CrudePrev                                  NaN
# CSMOKING_CrudePrev                               NaN
# OBESITY_CrudePrev                                NaN
# Median_Household_Income                          NaN
# ZCTA_pm2_5                                       NaN
# sdi_score                                        NaN
#
#                                  Pct_Black_Male_18andOver  \
# Pct_Civilian_Unemployed                               NaN
# Pct_BelowPoverty_18andOver                            NaN
# Pct_Population_Male_18andOver                         NaN
# Pct_Population_65andOver                              NaN
# Pct_Population_Male_65andOver                         NaN
# Pct_Population_Female_65andOver                       NaN
# Pct_Black_18andOver                              0.951843
# Pct_Black_Male_18andOver                         1.000000
# Pct_Black_Female_18andOver                       0.833802
# Pct_Black_65andOver                                   NaN
# Pct_Black_Male_65andOver                              NaN
# Pct_Black_Female_65andOver                            NaN
# Pct_White_18andOver                                   NaN
# Pct_White_Male_18andOver                              NaN
# Pct_White_Female_18andOver                            NaN
# Pct_White_65andOver                                   NaN
# Pct_White_Male_65andOver                              NaN
# Pct_White_Female_65andOver                            NaN
# Pct_Hisp_18andOver                                    NaN
# Pct_Hisp_Male_18andOver                               NaN
# Pct_Hisp_Female_18andOver                             NaN
# Pct_Hisp_65andOver                                    NaN
# Pct_Hisp_Male_65andOver                               NaN
# Pct_Hisp_Female_65andOver                             NaN
# BINGE_CrudePrev                                       NaN
# CSMOKING_CrudePrev                                    NaN
# OBESITY_CrudePrev                                     NaN
# Median_Household_Income                               NaN
# ZCTA_pm2_5                                            NaN
# sdi_score                                             NaN
#
#                                  Pct_Black_Female_18andOver  \
# Pct_Civilian_Unemployed                                 NaN
# Pct_BelowPoverty_18andOver                              NaN
# Pct_Population_Male_18andOver                           NaN
# Pct_Population_65andOver                                NaN
# Pct_Population_Male_65andOver                           NaN
# Pct_Population_Female_65andOver                         NaN
# Pct_Black_18andOver                                0.962904
# Pct_Black_Male_18andOver                           0.833802
# Pct_Black_Female_18andOver                         1.000000
# Pct_Black_65andOver                                0.795408
# Pct_Black_Male_65andOver                                NaN
# Pct_Black_Female_65andOver                         0.777455
# Pct_White_18andOver                                     NaN
# Pct_White_Male_18andOver                                NaN
# Pct_White_Female_18andOver                              NaN
# Pct_White_65andOver                                     NaN
# Pct_White_Male_65andOver                                NaN
# Pct_White_Female_65andOver                              NaN
# Pct_Hisp_18andOver                                      NaN
# Pct_Hisp_Male_18andOver                                 NaN
# Pct_Hisp_Female_18andOver                               NaN
# Pct_Hisp_65andOver                                      NaN
# Pct_Hisp_Male_65andOver                                 NaN
# Pct_Hisp_Female_65andOver                               NaN
# BINGE_CrudePrev                                         NaN
# CSMOKING_CrudePrev                                      NaN
# OBESITY_CrudePrev                                       NaN
# Median_Household_Income                                 NaN
# ZCTA_pm2_5                                              NaN
# sdi_score                                               NaN
#
#                                  Pct_Black_65andOver  ...  \
# Pct_Civilian_Unemployed                          NaN  ...
# Pct_BelowPoverty_18andOver                       NaN  ...
# Pct_Population_Male_18andOver                    NaN  ...
# Pct_Population_65andOver                         NaN  ...
# Pct_Population_Male_65andOver                    NaN  ...
# Pct_Population_Female_65andOver                  NaN  ...
# Pct_Black_18andOver                         0.798901  ...
# Pct_Black_Male_18andOver                         NaN  ...
# Pct_Black_Female_18andOver                  0.795408  ...
# Pct_Black_65andOver                         1.000000  ...
# Pct_Black_Male_65andOver                    0.887003  ...
# Pct_Black_Female_65andOver                  0.925878  ...
# Pct_White_18andOver                              NaN  ...
# Pct_White_Male_18andOver                         NaN  ...
# Pct_White_Female_18andOver                       NaN  ...
# Pct_White_65andOver                              NaN  ...
# Pct_White_Male_65andOver                         NaN  ...
# Pct_White_Female_65andOver                       NaN  ...
# Pct_Hisp_18andOver                               NaN  ...
# Pct_Hisp_Male_18andOver                          NaN  ...
# Pct_Hisp_Female_18andOver                        NaN  ...
# Pct_Hisp_65andOver                               NaN  ...
# Pct_Hisp_Male_65andOver                          NaN  ...
# Pct_Hisp_Female_65andOver                        NaN  ...
# BINGE_CrudePrev                                  NaN  ...
# CSMOKING_CrudePrev                               NaN  ...
# OBESITY_CrudePrev                                NaN  ...
# Median_Household_Income                          NaN  ...
# ZCTA_pm2_5                                       NaN  ...
# sdi_score                                        NaN  ...
#
#                                  Pct_Hisp_Female_18andOver  \
# Pct_Civilian_Unemployed                                NaN
# Pct_BelowPoverty_18andOver                             NaN
# Pct_Population_Male_18andOver                          NaN
# Pct_Population_65andOver                               NaN
# Pct_Population_Male_65andOver                          NaN
# Pct_Population_Female_65andOver                        NaN
# Pct_Black_18andOver                                    NaN
# Pct_Black_Male_18andOver                               NaN
# Pct_Black_Female_18andOver                             NaN
# Pct_Black_65andOver                                    NaN
# Pct_Black_Male_65andOver                               NaN
# Pct_Black_Female_65andOver                             NaN
# Pct_White_18andOver                                    NaN
# Pct_White_Male_18andOver                               NaN
# Pct_White_Female_18andOver                             NaN
# Pct_White_65andOver                                    NaN
# Pct_White_Male_65andOver                               NaN
# Pct_White_Female_65andOver                             NaN
# Pct_Hisp_18andOver                                0.937846
# Pct_Hisp_Male_18andOver                           0.779102
# Pct_Hisp_Female_18andOver                         1.000000
# Pct_Hisp_65andOver                                     NaN
# Pct_Hisp_Male_65andOver                                NaN
# Pct_Hisp_Female_65andOver                              NaN
# BINGE_CrudePrev                                        NaN
# CSMOKING_CrudePrev                                     NaN
# OBESITY_CrudePrev                                      NaN
# Median_Household_Income                                NaN
# ZCTA_pm2_5                                             NaN
# sdi_score                                              NaN
#
#                                  Pct_Hisp_65andOver  Pct_Hisp_Male_65andOver  \
# Pct_Civilian_Unemployed                         NaN                      NaN
# Pct_BelowPoverty_18andOver                      NaN                      NaN
# Pct_Population_Male_18andOver                   NaN                      NaN
# Pct_Population_65andOver                        NaN                      NaN
# Pct_Population_Male_65andOver                   NaN                      NaN
# Pct_Population_Female_65andOver                 NaN                      NaN
# Pct_Black_18andOver                             NaN                      NaN
# Pct_Black_Male_18andOver                        NaN                      NaN
# Pct_Black_Female_18andOver                      NaN                      NaN
# Pct_Black_65andOver                             NaN                      NaN
# Pct_Black_Male_65andOver                        NaN                      NaN
# Pct_Black_Female_65andOver                      NaN                      NaN
# Pct_White_18andOver                             NaN                      NaN
# Pct_White_Male_18andOver                        NaN                      NaN
# Pct_White_Female_18andOver                      NaN                      NaN
# Pct_White_65andOver                             NaN                      NaN
# Pct_White_Male_65andOver                        NaN                      NaN
# Pct_White_Female_65andOver                      NaN                      NaN
# Pct_Hisp_18andOver                              NaN                      NaN
# Pct_Hisp_Male_18andOver                         NaN                      NaN
# Pct_Hisp_Female_18andOver                       NaN                      NaN
# Pct_Hisp_65andOver                         1.000000                 0.772652
# Pct_Hisp_Male_65andOver                    0.772652                 1.000000
# Pct_Hisp_Female_65andOver                  0.879884                      NaN
# BINGE_CrudePrev                                 NaN                      NaN
# CSMOKING_CrudePrev                              NaN                      NaN
# OBESITY_CrudePrev                               NaN                      NaN
# Median_Household_Income                         NaN                      NaN
# ZCTA_pm2_5                                      NaN                      NaN
# sdi_score                                       NaN                      NaN
#
#                                  Pct_Hisp_Female_65andOver  BINGE_CrudePrev  \
# Pct_Civilian_Unemployed                                NaN              NaN
# Pct_BelowPoverty_18andOver                             NaN              NaN
# Pct_Population_Male_18andOver                          NaN              NaN
# Pct_Population_65andOver                               NaN              NaN
# Pct_Population_Male_65andOver                          NaN              NaN
# Pct_Population_Female_65andOver                        NaN              NaN
# Pct_Black_18andOver                                    NaN              NaN
# Pct_Black_Male_18andOver                               NaN              NaN
# Pct_Black_Female_18andOver                             NaN              NaN
# Pct_Black_65andOver                                    NaN              NaN
# Pct_Black_Male_65andOver                               NaN              NaN
# Pct_Black_Female_65andOver                             NaN              NaN
# Pct_White_18andOver                                    NaN              NaN
# Pct_White_Male_18andOver                               NaN              NaN
# Pct_White_Female_18andOver                             NaN              NaN
# Pct_White_65andOver                                    NaN              NaN
# Pct_White_Male_65andOver                               NaN              NaN
# Pct_White_Female_65andOver                             NaN              NaN
# Pct_Hisp_18andOver                                     NaN              NaN
# Pct_Hisp_Male_18andOver                                NaN              NaN
# Pct_Hisp_Female_18andOver                              NaN              NaN
# Pct_Hisp_65andOver                                0.879884              NaN
# Pct_Hisp_Male_65andOver                                NaN              NaN
# Pct_Hisp_Female_65andOver                         1.000000              NaN
# BINGE_CrudePrev                                        NaN              1.0
# CSMOKING_CrudePrev                                     NaN              NaN
# OBESITY_CrudePrev                                      NaN              NaN
# Median_Household_Income                                NaN              NaN
# ZCTA_pm2_5                                             NaN              NaN
# sdi_score                                              NaN              NaN
#
#                                  CSMOKING_CrudePrev  OBESITY_CrudePrev  \
# Pct_Civilian_Unemployed                         NaN                NaN
# Pct_BelowPoverty_18andOver                      NaN                NaN
# Pct_Population_Male_18andOver                   NaN                NaN
# Pct_Population_65andOver                        NaN                NaN
# Pct_Population_Male_65andOver                   NaN                NaN
# Pct_Population_Female_65andOver                 NaN                NaN
# Pct_Black_18andOver                             NaN                NaN
# Pct_Black_Male_18andOver                        NaN                NaN
# Pct_Black_Female_18andOver                      NaN                NaN
# Pct_Black_65andOver                             NaN                NaN
# Pct_Black_Male_65andOver                        NaN                NaN
# Pct_Black_Female_65andOver                      NaN                NaN
# Pct_White_18andOver                             NaN                NaN
# Pct_White_Male_18andOver                        NaN                NaN
# Pct_White_Female_18andOver                      NaN                NaN
# Pct_White_65andOver                             NaN                NaN
# Pct_White_Male_65andOver                        NaN                NaN
# Pct_White_Female_65andOver                      NaN                NaN
# Pct_Hisp_18andOver                              NaN                NaN
# Pct_Hisp_Male_18andOver                         NaN                NaN
# Pct_Hisp_Female_18andOver                       NaN                NaN
# Pct_Hisp_65andOver                              NaN                NaN
# Pct_Hisp_Male_65andOver                         NaN                NaN
# Pct_Hisp_Female_65andOver                       NaN                NaN
# BINGE_CrudePrev                                 NaN                NaN
# CSMOKING_CrudePrev                          1.00000            0.80936
# OBESITY_CrudePrev                           0.80936            1.00000
# Median_Household_Income                         NaN                NaN
# ZCTA_pm2_5                                      NaN                NaN
# sdi_score                                       NaN                NaN
#
#                                  Median_Household_Income  ZCTA_pm2_5  \
# Pct_Civilian_Unemployed                              NaN         NaN
# Pct_BelowPoverty_18andOver                           NaN         NaN
# Pct_Population_Male_18andOver                        NaN         NaN
# Pct_Population_65andOver                             NaN         NaN
# Pct_Population_Male_65andOver                        NaN         NaN
# Pct_Population_Female_65andOver                      NaN         NaN
# Pct_Black_18andOver                                  NaN         NaN
# Pct_Black_Male_18andOver                             NaN         NaN
# Pct_Black_Female_18andOver                           NaN         NaN
# Pct_Black_65andOver                                  NaN         NaN
# Pct_Black_Male_65andOver                             NaN         NaN
# Pct_Black_Female_65andOver                           NaN         NaN
# Pct_White_18andOver                                  NaN         NaN
# Pct_White_Male_18andOver                             NaN         NaN
# Pct_White_Female_18andOver                           NaN         NaN
# Pct_White_65andOver                                  NaN         NaN
# Pct_White_Male_65andOver                             NaN         NaN
# Pct_White_Female_65andOver                           NaN         NaN
# Pct_Hisp_18andOver                                   NaN         NaN
# Pct_Hisp_Male_18andOver                              NaN         NaN
# Pct_Hisp_Female_18andOver                            NaN         NaN
# Pct_Hisp_65andOver                                   NaN         NaN
# Pct_Hisp_Male_65andOver                              NaN         NaN
# Pct_Hisp_Female_65andOver                            NaN         NaN
# BINGE_CrudePrev                                      NaN         NaN
# CSMOKING_CrudePrev                                   NaN         NaN
# OBESITY_CrudePrev                                    NaN         NaN
# Median_Household_Income                              1.0         NaN
# ZCTA_pm2_5                                           NaN         1.0
# sdi_score                                            NaN         NaN
#
#                                  sdi_score
# Pct_Civilian_Unemployed                NaN
# Pct_BelowPoverty_18andOver        0.750921
# Pct_Population_Male_18andOver          NaN
# Pct_Population_65andOver               NaN
# Pct_Population_Male_65andOver          NaN
# Pct_Population_Female_65andOver        NaN
# Pct_Black_18andOver                    NaN
# Pct_Black_Male_18andOver               NaN
# Pct_Black_Female_18andOver             NaN
# Pct_Black_65andOver                    NaN
# Pct_Black_Male_65andOver               NaN
# Pct_Black_Female_65andOver             NaN
# Pct_White_18andOver                    NaN
# Pct_White_Male_18andOver               NaN
# Pct_White_Female_18andOver             NaN
# Pct_White_65andOver                    NaN
# Pct_White_Male_65andOver               NaN
# Pct_White_Female_65andOver             NaN
# Pct_Hisp_18andOver                     NaN
# Pct_Hisp_Male_18andOver                NaN
# Pct_Hisp_Female_18andOver              NaN
# Pct_Hisp_65andOver                     NaN
# Pct_Hisp_Male_65andOver                NaN
# Pct_Hisp_Female_65andOver              NaN
# BINGE_CrudePrev                        NaN
# CSMOKING_CrudePrev                     NaN
# OBESITY_CrudePrev                      NaN
# Median_Household_Income                NaN
# ZCTA_pm2_5                             NaN
# sdi_score                         1.000000
#
# [30 rows x 30 columns]

# %%
## Pairwise high pearson correlation coefficient >= 0.75



mask = (corrdata.notna()) & (corrdata != 1)



RowsNames = corrdata.index.tolist()



ColumnNames = corrdata.columns.tolist()




# Extract row-column pairs




pairs = [(RowsNames[row], ColumnNames[col]) for row, col in zip(*np.where(mask))]



# Convert to a DataFrame



HcorrelatedPairs = pd.DataFrame(pairs, columns = ["Feature 1", "Feature 2"])




HcorrelatedPairs.sort_values(by = "Feature 1",  inplace = True)


HcorrelatedPairs


mask = (corrdata.notna()) & (corrdata != 1)



upper_triangle_mask = mask & (np.triu(np.ones(mask.shape), k = 1).astype(bool))



# Get row and column names



RowsNames = corrdata.index.tolist()



ColumnNames = corrdata.columns.tolist()




pairs = [(RowsNames[row], ColumnNames[col]) for row, col in zip(*np.where(upper_triangle_mask))]




HcorrelatedPairs = pd.DataFrame(pairs, columns=["Feature 1", "Feature 2"])





HcorrelatedPairs.sort_values(by = "Feature 1", inplace = False)




HcorrelatedPairs
# Out:
#                           Feature 1                        Feature 2
# 0        Pct_BelowPoverty_18andOver                        sdi_score
# 1          Pct_Population_65andOver    Pct_Population_Male_65andOver
# 2          Pct_Population_65andOver  Pct_Population_Female_65andOver
# 3          Pct_Population_65andOver              Pct_White_65andOver
# 4          Pct_Population_65andOver         Pct_White_Male_65andOver
# 5          Pct_Population_65andOver       Pct_White_Female_65andOver
# 6     Pct_Population_Male_65andOver              Pct_White_65andOver
# 7     Pct_Population_Male_65andOver         Pct_White_Male_65andOver
# 8   Pct_Population_Female_65andOver              Pct_White_65andOver
# 9   Pct_Population_Female_65andOver       Pct_White_Female_65andOver
# 10              Pct_Black_18andOver         Pct_Black_Male_18andOver
# 11              Pct_Black_18andOver       Pct_Black_Female_18andOver
# 12              Pct_Black_18andOver              Pct_Black_65andOver
# 13         Pct_Black_Male_18andOver       Pct_Black_Female_18andOver
# 14       Pct_Black_Female_18andOver              Pct_Black_65andOver
# 15       Pct_Black_Female_18andOver       Pct_Black_Female_65andOver
# 16              Pct_Black_65andOver         Pct_Black_Male_65andOver
# 17              Pct_Black_65andOver       Pct_Black_Female_65andOver
# 18              Pct_White_18andOver         Pct_White_Male_18andOver
# 19              Pct_White_18andOver       Pct_White_Female_18andOver
# 20              Pct_White_65andOver         Pct_White_Male_65andOver
# 21              Pct_White_65andOver       Pct_White_Female_65andOver
# 22               Pct_Hisp_18andOver          Pct_Hisp_Male_18andOver
# 23               Pct_Hisp_18andOver        Pct_Hisp_Female_18andOver
# 24          Pct_Hisp_Male_18andOver        Pct_Hisp_Female_18andOver
# 25               Pct_Hisp_65andOver          Pct_Hisp_Male_65andOver
# 26               Pct_Hisp_65andOver        Pct_Hisp_Female_65andOver
# 27               CSMOKING_CrudePrev                OBESITY_CrudePrev

# %%
np.ones(mask.shape).shape
# Out:
# (30, 30)

# %%
np.unique(HcorrelatedPairs["Feature 1"])
# Out:
# array(['CSMOKING_CrudePrev', 'Pct_BelowPoverty_18andOver',
#        'Pct_Black_18andOver', 'Pct_Black_65andOver',
#        'Pct_Black_Female_18andOver', 'Pct_Black_Male_18andOver',
#        'Pct_Hisp_18andOver', 'Pct_Hisp_65andOver',
#        'Pct_Hisp_Male_18andOver', 'Pct_Population_65andOver',
#        'Pct_Population_Female_65andOver', 'Pct_Population_Male_65andOver',
#        'Pct_White_18andOver', 'Pct_White_65andOver'], dtype=object)

# %% [markdown]
# ## Features
#
# We exclude variables whose values can cover the values of the other variables
#
#
#
# Subset variables are considered
#
#
# It means that, for instance, instead of considering the entire population, we account for differences based on gender
#
#
# What about the other way around?
#
#
#
# Variables that may be included in the modelling
#
#
#
# * Pct_BelowPoverty_18andOver
#
#
#
# * sdi_score
#
#
#
# * Pct_White_Male_65andOver
#
#
#
# * Pct_White_Female_65andOver
#
#
#
# * Pct_Black_Female_65andOver
#
#
#
# * Pct_Black_Male_65andOver
#
#
#
# * Pct_Hisp_Male_65andOver
#
#
#
# * Pct_Hisp_Female_65andOver
#
#
#
# * OBESITY_CrudePrev
#
#
#
# * CSMOKING_CrudePrev
#
#
#
# * Pct_Civilian_Unemployed
#
#
#
# * BINGE_CrudePrev
#
#
#
# * Median_Household_Income
#
#
#
# * ZCTA_pm2_5

# %% [markdown]
# ## Feature engineering or creation
#
#
#
# * Pct_White_Male_18andUnder65 = Pct_White_Male_18andOver - Pct_White_Male_65andOver
#
#
#
# * Pct_White_Female_18andUnder65 = Pct_White_Female_18andOver - Pct_White_Female_65andOver
#
#
#
# * Pct_Black_Female_18andUnder65 = Pct_Black_Female_18andOver - Pct_Black_Female_65andOver
#
#
#
# * Pct_Black_Male_18andUnder65 = Pct_Black_Male_18andOver - Pct_Black_Male_65andOver
#
#
#
# * Pct_Hisp_Male_18andUnder65 = Pct_Hisp_Male_18andOver - Pct_Hisp_Male_65andOver
#
#
#
# * Pct_Hisp_Female_18andUnder65 = Pct_Hisp_Female_18andOver - Pct_Hisp_Female_65andOver

# %%
xdata.head()
# Out:
#    Pct_Civilian_Unemployed  Pct_BelowPoverty_18andOver  \
# 0                      2.3                    1.907688
# 1                      4.6                   12.441946
# 2                      4.5                    9.415209
# 3                      5.6                    7.276174
# 4                      5.6                    8.663903
#
#    Pct_Population_Male_18andOver  Pct_Population_65andOver  \
# 0                      48.342384                  9.024007
# 1                      49.278905                 26.766072
# 2                      49.808468                  8.959626
# 3                      51.022447                 12.299881
# 4                      51.306431                 11.569619
#
#    Pct_Population_Male_65andOver  Pct_Population_Female_65andOver  \
# 0                       4.801372                         4.222635
# 1                      13.664141                        13.101931
# 2                       3.328926                         5.630699
# 3                       5.479870                         6.820011
# 4                       5.480546                         6.089073
#
#    Pct_Black_18andOver  Pct_Black_Male_18andOver  Pct_Black_Female_18andOver  \
# 0            11.138897                  5.244356                    5.894541
# 1             3.299927                  1.686629                    1.613297
# 2            16.742940                  7.993491                    8.749449
# 3            14.608363                  8.135179                    6.473183
# 4             9.629940                  5.339824                    4.290115
#
#    Pct_Black_65andOver  ...  OBESITY_CrudePrev  Median_Household_Income  \
# 0             0.685910  ...               22.5                 153314.0
# 1             0.562210  ...               32.2                  82500.0
# 2             1.247500  ...               36.6                  70629.0
# 3             1.459449  ...               31.7                  81042.0
# 4             1.361579  ...               33.8                  88207.0
#
#    ZCTA_pm2_5  sdi_score  Pct_White_Male_Between18and65  \
# 0    7.801598        1.0                      24.242641
# 1    7.171176       18.0                      32.437057
# 2    7.940322       72.0                      27.329740
# 3    8.013779       50.0                      29.014178
# 4    8.080360       56.0                      31.129959
#
#    Pct_White_Female_Between18and65  Pct_Black_Female_Between18and65  \
# 0                        24.607031                         5.487282
# 1                        34.685896                         1.613297
# 2                        25.495780                         7.922302
# 3                        28.844927                         5.651896
# 4                        29.057164                         3.822310
#
#    Pct_Black_Male_Between18and65  Pct_Hisp_Male_Between18and65  \
# 0                       4.965704                      3.801086
# 1                       1.124419                      0.024444
# 2                       7.573138                     17.732805
# 3                       7.497017                     14.896923
# 4                       4.446050                     17.616856
#
#    Pct_Hisp_Female_Between18and65
# 0                        3.772506
# 1                        2.371058
# 2                       16.149700
# 3                       13.226603
# 4                       14.152056
#
# [5 rows x 36 columns]

# %%
xdata.columns
# Out:
# Index(['Pct_Civilian_Unemployed', 'Pct_BelowPoverty_18andOver',
#        'Pct_Population_Male_18andOver', 'Pct_Population_65andOver',
#        'Pct_Population_Male_65andOver', 'Pct_Population_Female_65andOver',
#        'Pct_Black_18andOver', 'Pct_Black_Male_18andOver',
#        'Pct_Black_Female_18andOver', 'Pct_Black_65andOver',
#        'Pct_Black_Male_65andOver', 'Pct_Black_Female_65andOver',
#        'Pct_White_18andOver', 'Pct_White_Male_18andOver',
#        'Pct_White_Female_18andOver', 'Pct_White_65andOver',
#        'Pct_White_Male_65andOver', 'Pct_White_Female_65andOver',
#        'Pct_Hisp_18andOver', 'Pct_Hisp_Male_18andOver',
#        'Pct_Hisp_Female_18andOver', 'Pct_Hisp_65andOver',
#        'Pct_Hisp_Male_65andOver', 'Pct_Hisp_Female_65andOver',
#        'BINGE_CrudePrev', 'CSMOKING_CrudePrev', 'OBESITY_CrudePrev',
#        'Median_Household_Income', 'ZCTA_pm2_5', 'sdi_score',
#        'Pct_White_Male_Between18and65', 'Pct_White_Female_Between18and65',
#        'Pct_Black_Female_Between18and65', 'Pct_Black_Male_Between18and65',
#        'Pct_Hisp_Male_Between18and65', 'Pct_Hisp_Female_Between18and65'],
#       dtype='object')

# %%
xdata["Pct_White_Male_Between18and65"] = xdata["Pct_White_Male_18andOver"] - xdata["Pct_White_Male_65andOver"]



xdata["Pct_White_Female_Between18and65"] = xdata["Pct_White_Female_18andOver"] - xdata["Pct_White_Female_65andOver"]



xdata["Pct_Black_Female_Between18and65"] = xdata["Pct_Black_Female_18andOver"] - xdata["Pct_Black_Female_65andOver"]



xdata["Pct_Black_Male_Between18and65"] = xdata["Pct_Black_Male_18andOver"] - xdata["Pct_Black_Male_65andOver"]



xdata["Pct_Hisp_Male_Between18and65"] = xdata["Pct_Hisp_Male_18andOver"] - xdata["Pct_Hisp_Male_65andOver"]




xdata["Pct_Hisp_Female_Between18and65"] = xdata["Pct_Hisp_Female_18andOver"] - xdata["Pct_Hisp_Female_65andOver"]

# %%
z = xdata>=0


pd.DataFrame({"All are positive":   z.sum()})
# Out:
#                                  All are positive
# Pct_Civilian_Unemployed                       788
# Pct_BelowPoverty_18andOver                    788
# Pct_Population_Male_18andOver                 788
# Pct_Population_65andOver                      788
# Pct_Population_Male_65andOver                 788
# Pct_Population_Female_65andOver               788
# Pct_Black_18andOver                           788
# Pct_Black_Male_18andOver                      788
# Pct_Black_Female_18andOver                    788
# Pct_Black_65andOver                           788
# Pct_Black_Male_65andOver                      788
# Pct_Black_Female_65andOver                    788
# Pct_White_18andOver                           788
# Pct_White_Male_18andOver                      788
# Pct_White_Female_18andOver                    788
# Pct_White_65andOver                           788
# Pct_White_Male_65andOver                      788
# Pct_White_Female_65andOver                    788
# Pct_Hisp_18andOver                            788
# Pct_Hisp_Male_18andOver                       788
# Pct_Hisp_Female_18andOver                     788
# Pct_Hisp_65andOver                            788
# Pct_Hisp_Male_65andOver                       788
# Pct_Hisp_Female_65andOver                     788
# BINGE_CrudePrev                               788
# CSMOKING_CrudePrev                            788
# OBESITY_CrudePrev                             788
# Median_Household_Income                       788
# ZCTA_pm2_5                                    788
# sdi_score                                     788
# Pct_White_Male_Between18and65                 788
# Pct_White_Female_Between18and65               788
# Pct_Black_Female_Between18and65               788
# Pct_Black_Male_Between18and65                 788
# Pct_Hisp_Male_Between18and65                  788
# Pct_Hisp_Female_Between18and65                788

# %%
xdata.columns
# Out:
# Index(['Pct_Civilian_Unemployed', 'Pct_BelowPoverty_18andOver',
#        'Pct_Population_Male_18andOver', 'Pct_Population_65andOver',
#        'Pct_Population_Male_65andOver', 'Pct_Population_Female_65andOver',
#        'Pct_Black_18andOver', 'Pct_Black_Male_18andOver',
#        'Pct_Black_Female_18andOver', 'Pct_Black_65andOver',
#        'Pct_Black_Male_65andOver', 'Pct_Black_Female_65andOver',
#        'Pct_White_18andOver', 'Pct_White_Male_18andOver',
#        'Pct_White_Female_18andOver', 'Pct_White_65andOver',
#        'Pct_White_Male_65andOver', 'Pct_White_Female_65andOver',
#        'Pct_Hisp_18andOver', 'Pct_Hisp_Male_18andOver',
#        'Pct_Hisp_Female_18andOver', 'Pct_Hisp_65andOver',
#        'Pct_Hisp_Male_65andOver', 'Pct_Hisp_Female_65andOver',
#        'BINGE_CrudePrev', 'CSMOKING_CrudePrev', 'OBESITY_CrudePrev',
#        'Median_Household_Income', 'ZCTA_pm2_5', 'sdi_score',
#        'Pct_White_Male_Between18and65', 'Pct_White_Female_Between18and65',
#        'Pct_Black_Female_Between18and65', 'Pct_Black_Male_Between18and65',
#        'Pct_Hisp_Male_Between18and65', 'Pct_Hisp_Female_Between18and65'],
#       dtype='object')

# %%
## Summary of the features included in the modelling

xcol = ['Pct_Civilian_Unemployed', 'Pct_BelowPoverty_18andOver',
       'Pct_Population_Male_65andOver', 'Pct_Population_Female_65andOver',
       'Pct_Black_65andOver','Pct_Black_Male_65andOver', 'Pct_Black_Female_65andOver',
       'Pct_White_65andOver','Pct_White_Male_65andOver', 'Pct_White_Female_65andOver',
       'Pct_Hisp_65andOver', 'Pct_Hisp_Male_65andOver', 'Pct_Hisp_Female_65andOver',
       'BINGE_CrudePrev', 'CSMOKING_CrudePrev', 'OBESITY_CrudePrev',
       'Median_Household_Income', 'ZCTA_pm2_5', 'sdi_score','Pct_White_Male_Between18and65', 
       'Pct_White_Female_Between18and65',
       'Pct_Black_Female_Between18and65', 'Pct_Black_Male_Between18and65',
       'Pct_Hisp_Male_Between18and65', 'Pct_Hisp_Female_Between18and65']

# %%
x = xdata[xcol]


x
# Out:
#      Pct_Civilian_Unemployed  Pct_BelowPoverty_18andOver  \
# 0                        2.3                    1.907688
# 1                        4.6                   12.441946
# 2                        4.5                    9.415209
# 3                        5.6                    7.276174
# 4                        5.6                    8.663903
# ..                       ...                         ...
# 891                      5.9                   26.901408
# 892                      8.4                   20.799660
# 893                      6.7                   12.025316
# 894                      2.9                   23.047538
# 895                     12.8                   19.776119
#
#      Pct_Population_Male_65andOver  Pct_Population_Female_65andOver  \
# 0                         4.801372                         4.222635
# 1                        13.664141                        13.101931
# 2                         3.328926                         5.630699
# 3                         5.479870                         6.820011
# 4                         5.480546                         6.089073
# ..                             ...                              ...
# 891                      11.267606                         7.887324
# 892                       7.230966                         5.869843
# 893                      11.329935                        15.129750
# 894                      13.412564                        16.256367
# 895                      11.194030                         3.731343
#
#      Pct_Black_65andOver  Pct_Black_Male_65andOver  \
# 0               0.685910                  0.278651
# 1               0.562210                  0.562210
# 2               1.247500                  0.420353
# 3               1.459449                  0.638162
# 4               1.361579                  0.893774
# ..                   ...                       ...
# 891             0.000000                  0.000000
# 892             0.000000                  0.000000
# 893             0.417053                  0.185357
# 894             0.000000                  0.000000
# 895             1.492537                  1.492537
#
#      Pct_Black_Female_65andOver  Pct_White_65andOver  \
# 0                      0.407259             4.779937
# 1                      0.000000            25.054999
# 2                      0.827147             5.800197
# 3                      0.821287             9.725035
# 4                      0.467805             8.739969
# ..                          ...                  ...
# 891                    0.000000            19.154930
# 892                    0.000000            13.100808
# 893                    0.231696            25.857275
# 894                    0.000000            29.668930
# 895                    0.000000            13.432836
#
#      Pct_White_Male_65andOver  Pct_White_Female_65andOver  ...  \
# 0                    2.657902                    2.122035  ...
# 1                   12.784160                   12.270838  ...
# 2                    2.108546                    3.691651  ...
# 3                    4.242391                    5.482645  ...
# 4                    3.966835                    4.773134  ...
# ..                        ...                         ...  ...
# 891                 11.267606                    7.887324  ...
# 892                  7.230966                    5.869843  ...
# 893                 11.144578                   14.712697  ...
# 894                 13.412564                   16.256367  ...
# 895                  9.701493                    3.731343  ...
#
#      OBESITY_CrudePrev  Median_Household_Income  ZCTA_pm2_5  sdi_score  \
# 0                 22.5                 153314.0    7.801598        1.0
# 1                 32.2                  82500.0    7.171176       18.0
# 2                 36.6                  70629.0    7.940322       72.0
# 3                 31.7                  81042.0    8.013779       50.0
# 4                 33.8                  88207.0    8.080360       56.0
# ..                 ...                      ...         ...        ...
# 891               35.9                  25625.0    8.217162       60.0
# 892               36.7                  41318.0    8.007121       52.0
# 893               38.7                  47820.0    7.577166       54.0
# 894               36.6                  34668.0    8.219753       45.0
# 895               34.9                  38203.0    8.010354       57.0
#
#      Pct_White_Male_Between18and65  Pct_White_Female_Between18and65  \
# 0                        24.242641                        24.607031
# 1                        32.437057                        34.685896
# 2                        27.329740                        25.495780
# 3                        29.014178                        28.844927
# 4                        31.129959                        29.057164
# ..                             ...                              ...
# 891                      43.098592                        37.746479
# 892                      43.002977                        43.130583
# 893                      34.291010                        32.924004
# 894                      39.176570                        30.645161
# 895                      35.447761                        48.880597
#
#      Pct_Black_Female_Between18and65  Pct_Black_Male_Between18and65  \
# 0                           5.487282                       4.965704
# 1                           1.613297                       1.124419
# 2                           7.922302                       7.573138
# 3                           5.651896                       7.497017
# 4                           3.822310                       4.446050
# ..                               ...                            ...
# 891                         0.000000                       0.000000
# 892                         0.000000                       0.000000
# 893                         0.741427                       2.988879
# 894                         0.000000                       0.000000
# 895                         0.000000                       0.000000
#
#      Pct_Hisp_Male_Between18and65  Pct_Hisp_Female_Between18and65
# 0                        3.801086                        3.772506
# 1                        0.024444                        2.371058
# 2                       17.732805                       16.149700
# 3                       14.896923                       13.226603
# 4                       17.616856                       14.152056
# ..                            ...                             ...
# 891                      0.000000                        0.000000
# 892                      0.765632                        0.000000
# 893                      0.278035                        0.000000
# 894                      0.509338                        0.000000
# 895                      0.000000                        0.000000
#
# [788 rows x 25 columns]

# %%
x.shape
# Out:
# (788, 25)

# %% [markdown]
# ## Feature transformation
#
# The aim of the work is to model the lung cancer positive cases using features
#
#
# The columns in the data are very heterogeneous with different scales, possibly very unevenly distributed
#
#
# To fit the proposed model to the data,  it is necessary to perform standard feature transformations

# %%
Percent2DecimalTransformer = make_pipeline(FunctionTransformer(lambda X: X / 100, validate = True))



StandardScaleTransformer = make_pipeline(StandardScaler())



Feature_preprocessing = ColumnTransformer([
    
    
    
    
        ("PercentToDecimal", Percent2DecimalTransformer, ["Pct_Civilian_Unemployed", 
                            "Pct_BelowPoverty_18andOver",
                            "Pct_Population_Male_65andOver", "Pct_Population_Female_65andOver",
                            "Pct_Black_65andOver","Pct_Black_Male_65andOver", 'Pct_Black_Female_65andOver',
                            "Pct_White_65andOver","Pct_White_Male_65andOver", "Pct_White_Female_65andOver",
                            "Pct_Hisp_65andOver", "Pct_Hisp_Male_65andOver", "Pct_Hisp_Female_65andOver",
                            "Pct_White_Male_Between18and65", "Pct_White_Female_Between18and65",
                            "Pct_Black_Female_Between18and65", "Pct_Black_Male_Between18and65",
                            "Pct_Hisp_Male_Between18and65", "Pct_Hisp_Female_Between18and65"]),
        
    
    
        ("StandardScaleTransformer",StandardScaleTransformer, ["BINGE_CrudePrev", "CSMOKING_CrudePrev", 
                                                       
                                                       "OBESITY_CrudePrev",
                                                       "Median_Household_Income", "ZCTA_pm2_5", "sdi_score"])])

# %%
Feature_preprocessing
# Out:
# ColumnTransformer(transformers=[('PercentToDecimal',
#                                  Pipeline(steps=[('functiontransformer',
#                                                   FunctionTransformer(func=<function <lambda> at 0x1533c1c60>,
#                                                                       validate=True))]),
#                                  ['Pct_Civilian_Unemployed',
#                                   'Pct_BelowPoverty_18andOver',
#                                   'Pct_Population_Male_65andOver',
#                                   'Pct_Population_Female_65andOver',
#                                   'Pct_Black_65andOver',
#                                   'Pct_Black_Male_65andOver',
#                                   'Pct_Black_Fe...
#                                   'Pct_White_Female_Between18and65',
#                                   'Pct_Black_Female_Between18and65',
#                                   'Pct_Black_Male_Between18and65',
#                                   'Pct_Hisp_Male_Between18and65',
#                                   'Pct_Hisp_Female_Between18and65']),
#                                 ('StandardScaleTransformer',
#                                  Pipeline(steps=[('standardscaler',
#                                                   StandardScaler())]),
#                                  ['BINGE_CrudePrev', 'CSMOKING_CrudePrev',
#                                   'OBESITY_CrudePrev',
#                                   'Median_Household_Income', 'ZCTA_pm2_5',
#                                   'sdi_score'])])

# %%
N
# Out:
# 0      13996
# 1       4091
# 2      29499
# 3      36041
# 4      26293
#        ...
# 891      710
# 892     2351
# 893     4316
# 894     2356
# 895      268
# Name: Population_18andOver, Length: 788, dtype: int64

# %%
x_train, x_test, y_train, y_test, N_train, N_test = train_test_split(x, y, N, test_size = 0.3, random_state = 42)

# %%
x_train.head()
# Out:
#      Pct_Civilian_Unemployed  Pct_BelowPoverty_18andOver  \
# 670                      5.6                   28.135629
# 623                      0.0                    8.541973
# 27                       3.0                    2.527292
# 152                      7.1                    8.501027
# 307                      0.0                    2.526003
#
#      Pct_Population_Male_65andOver  Pct_Population_Female_65andOver  \
# 670                       7.637306                         9.031088
# 623                      14.138439                        10.898380
# 27                        8.439154                        10.954978
# 152                      12.689938                        11.457906
# 307                      24.665676                        20.802377
#
#      Pct_Black_65andOver  Pct_Black_Male_65andOver  \
# 670             1.150259                  0.575130
# 623             0.000000                  0.000000
# 27              1.281796                  0.569245
# 152             5.174538                  2.505133
# 307             0.000000                  0.000000
#
#      Pct_Black_Female_65andOver  Pct_White_65andOver  \
# 670                    0.575130            15.409326
# 623                    0.000000            25.036819
# 27                     0.712551            14.943673
# 152                    2.669405            18.973306
# 307                    0.000000            41.753343
#
#      Pct_White_Male_65andOver  Pct_White_Female_65andOver  ...  \
# 670                  6.968912                    8.440415  ...
# 623                 14.138439                   10.898380  ...
# 27                   6.544325                    8.399347  ...
# 152                 10.184805                    8.788501  ...
# 307                 24.665676                   17.087667  ...
#
#      OBESITY_CrudePrev  Median_Household_Income  ZCTA_pm2_5  sdi_score  \
# 670               30.6                  48411.0    7.508014       59.0
# 623               30.6                  72563.0    7.392398       17.0
# 27                31.0                 131184.0    7.833080        2.0
# 152               33.3                  44115.0    7.504450       38.0
# 307               29.8                  58261.0    7.120594        4.0
#
#      Pct_White_Male_Between18and65  Pct_White_Female_Between18and65  \
# 670                      37.580311                        38.015544
# 623                      40.206186                        27.540501
# 27                       27.427252                        26.834123
# 152                      24.845996                        31.909651
# 307                      22.288262                        21.545319
#
#      Pct_Black_Female_Between18and65  Pct_Black_Male_Between18and65  \
# 670                         3.207254                       1.575130
# 623                         0.000000                       0.000000
# 27                          5.815851                       4.553959
# 152                         5.420945                      11.334702
# 307                         9.361070                       0.000000
#
#      Pct_Hisp_Male_Between18and65  Pct_Hisp_Female_Between18and65
# 670                      0.642487                        0.554404
# 623                      0.000000                        0.000000
# 27                       4.557940                        4.868437
# 152                      1.765914                        0.739220
# 307                      0.000000                        0.000000
#
# [5 rows x 25 columns]

# %%
x_test.head()
# Out:
#      Pct_Civilian_Unemployed  Pct_BelowPoverty_18andOver  \
# 651                      5.4                    9.920635
# 42                       2.6                    9.323803
# 234                      3.3                    5.862458
# 221                      3.8                   15.130193
# 260                      2.7                   10.481414
#
#      Pct_Population_Male_65andOver  Pct_Population_Female_65andOver  \
# 651                      17.619048                        16.428571
# 42                        8.056185                        10.833963
# 234                       8.117249                        10.372041
# 221                       7.659630                        10.091465
# 260                      12.065814                        10.725168
#
#      Pct_Black_65andOver  Pct_Black_Male_65andOver  \
# 651             0.000000                  0.000000
# 42              0.730663                  0.327538
# 234             0.000000                  0.000000
# 221             0.866964                  0.377129
# 260            14.929921                  7.434491
#
#      Pct_Black_Female_65andOver  Pct_White_65andOver  \
# 651                    0.000000            34.047619
# 42                     0.403124            15.847821
# 234                    0.000000            18.489290
# 221                    0.489835            16.641380
# 260                    7.495430             7.861060
#
#      Pct_White_Male_65andOver  Pct_White_Female_65andOver  ...  \
# 651                 17.619048                   16.428571  ...
# 42                   6.689342                    9.158478  ...
# 234                  8.117249                   10.372041  ...
# 221                  7.135116                    9.506264  ...
# 260                  4.631322                    3.229738  ...
#
#      OBESITY_CrudePrev  Median_Household_Income  ZCTA_pm2_5  sdi_score  \
# 651               36.2                  34914.0    7.479898       33.0
# 42                22.8                 106929.0    8.324991       40.0
# 234               34.2                  72328.0    7.159498        6.0
# 221               32.2                  47684.0    7.182274       76.0
# 260               35.5                  51618.0    7.301255       43.0
#
#      Pct_White_Male_Between18and65  Pct_White_Female_Between18and65  \
# 651                      31.984127                        33.809524
# 42                       29.232804                        29.617032
# 234                      39.571590                        41.939121
# 221                      32.454809                        35.441502
# 260                      20.962828                        21.633151
#
#      Pct_Black_Female_Between18and65  Pct_Black_Male_Between18and65  \
# 651                         0.000000                       0.000000
# 42                          4.213908                       4.106828
# 234                         0.000000                       0.000000
# 221                         2.800295                       3.138411
# 260                        19.987812                      14.137721
#
#      Pct_Hisp_Male_Between18and65  Pct_Hisp_Female_Between18and65
# 651                      0.000000                        0.000000
# 42                       5.120937                        4.976064
# 234                      0.000000                        0.000000
# 221                      8.947072                        8.409554
# 260                      3.046923                        1.340646
#
# [5 rows x 25 columns]

# %%
y_train.head()
# Out:
# 670    74.0
# 623     7.0
# 27     72.0
# 152    17.0
# 307     5.0
# Name: case_n_18plus, dtype: float64

# %%
y_test.head()
# Out:
# 651     9.0
# 42     33.0
# 234     6.0
# 221    93.0
# 260     6.0
# Name: case_n_18plus, dtype: float64

# %%
N_train.head()
# Out:
# 670    19300
# 623      679
# 27     25121
# 152     2435
# 307      673
# Name: Population_18andOver, dtype: int64

# %%
N_test.head()
# Out:
# 651     1260
# 42     15876
# 234      887
# 221    23069
# 260     1641
# Name: Population_18andOver, dtype: int64

# %%
print("Train data")


print(y_train.shape)


print(x_train.shape)


print(N_train.shape)



print("Test data")


print(y_test.shape)


print(x_test.shape)


print(N_test.shape)
# Out:
# Train data
# (551,)
# (551, 25)
# (551,)
# Test data
# (237,)
# (237, 25)
# (237,)

# %% [markdown]
# ##  XGBoost Poisson model

# %%
## Define XGBoost-based Poisson regression pipeline



## max_depth -- Tree depth 3 to 10 --- Lower for small data, higher for large data



## Learning_rate -- Step size for updates 0.01 to 0.3 --- Lower values need more trees



## n_estimators -- Number of trees 100 to 1000 --- More trees help with low learning rates



poisson_xgb = Pipeline([("preprocessor", Feature_preprocessing),
                        
                        
                        
    ("regressor", XGBRegressor(objective="count:poisson", max_depth = 6, learning_rate = 0.1, n_estimators=100))])








# Define parameters



params = {"objective": "count:poisson",  # Poisson regression
          
          
          
          "eval_metric": "poisson-nloglik",  # Negative log-likelihood for Poisson
          
          
          
          "learning_rate": 0.1,
          
          
          
          "max_depth": 3,
          
          
          
         "lambda": 1.0  # L2 regularization
          
                 
         }










 # Train model
    
    
    
poisson_xgb.fit(x_train, y_train)  # Train the pipeline
    
    
    
y_pred = poisson_xgb.predict(x_test)  # Predict normally

# %%
y_pred
# Out:
# array([  7.590232 ,  52.01815  ,   8.27081  ,  79.791954 ,  13.631049 ,
#        104.09875  ,  10.777783 , 131.73366  ,  15.4412565,  52.263992 ,
#          5.085667 ,  16.286703 ,  19.159023 ,  11.208244 ,  21.88275  ,
#         44.277424 ,  33.3581   ,  19.360851 , 113.6955   ,  13.04589  ,
#        113.71003  ,  81.657646 ,  11.830864 ,  28.659445 ,  22.64587  ,
#         29.010668 ,  14.77417  ,   6.0120564,   6.548296 ,  22.433056 ,
#          7.1444736,  35.598763 ,   9.314118 ,  84.90804  ,  41.138256 ,
#          6.8609185,   6.9689555,   6.2513776,   9.197101 ,  13.225161 ,
#         11.195988 ,  22.069784 ,  51.5878   ,  12.6874   ,  40.18343  ,
#          7.5965757,  72.711494 ,   8.301154 ,   4.086849 ,  42.987106 ,
#         12.342265 ,   7.95013  ,   6.009666 ,  56.237453 ,  27.881073 ,
#          4.2835045,   5.507873 ,  67.22428  ,   6.3154664,  30.628057 ,
#         18.854855 ,   8.301878 ,  50.876503 ,   4.185866 ,  53.93595  ,
#         26.766844 ,   4.585818 ,   7.7195053,  67.16052  ,  28.645174 ,
#          5.8543625,   7.0044127, 148.81616  ,  11.132786 ,   2.0425942,
#          9.126579 ,  40.727352 ,  25.949669 ,   8.593843 ,  98.2197   ,
#          4.6445203,  49.39766  ,  49.466724 ,   4.432842 ,  10.091452 ,
#         17.142996 ,  50.780003 ,  21.928274 ,  28.49065  ,  51.261353 ,
#          7.3026357,  31.179466 , 127.8961   ,  18.838112 ,  50.210396 ,
#         12.602591 ,  20.547655 ,  15.985282 ,  10.423842 ,  45.469666 ,
#         33.609898 ,  34.025837 ,  29.409376 ,   3.727974 ,   3.7380373,
#         42.135525 ,  26.494389 ,   4.678452 ,  47.727062 ,  11.370051 ,
#          8.617782 ,  11.788058 ,   3.5804744,   4.6375675,  96.379135 ,
#         20.824093 ,  68.873055 ,  26.156006 ,   7.6418552,   4.5601254,
#         45.446507 ,  18.572777 ,  54.130424 ,   2.7339997,   5.549222 ,
#         39.23312  ,  13.526707 ,  27.847956 ,  28.628017 ,  13.830263 ,
#         21.57957  ,  10.880168 ,   3.7354605,  55.593002 ,  18.986704 ,
#         33.25297  ,  98.32012  ,   4.810423 , 102.55153  ,  10.765831 ,
#         57.57073  ,  17.400978 ,  28.297047 ,   8.360713 ,   6.9569464,
#        123.803314 ,   3.9036887,  10.114479 ,   6.828733 , 104.804955 ,
#         25.942072 ,  22.903374 ,  66.63549  ,  33.03923  ,  72.196304 ,
#         33.2796   ,   5.0553703,   2.3988101,   5.5801673,   3.4114013,
#         23.072063 ,  13.71472  ,  51.06905  ,   9.202802 , 119.47536  ,
#         11.00716  ,   4.2647295,  12.412422 ,  20.20532  ,  12.109161 ,
#         10.183494 ,  42.444843 ,  33.432053 ,  37.976738 ,  16.577251 ,
#          7.39285  , 108.184425 ,  13.152731 ,  19.861437 ,  18.139503 ,
#          5.207552 ,  66.42567  ,  28.3923   ,   5.3447933,  12.142029 ,
#         20.64187  ,   2.7646236,  39.46129  ,   9.6353245,  16.464697 ,
#         43.83043  ,  43.620907 ,  44.191658 ,   2.2844496,  45.24165  ,
#          3.3097923,  99.21536  ,  49.79472  ,  59.3214   ,   5.9118896,
#         30.262375 ,  82.17159  ,  11.926083 ,   3.6477678,   9.59597  ,
#          6.5303407,  41.203777 ,  46.65637  ,   9.377149 ,  86.88984  ,
#         13.386396 ,  12.108093 ,   6.6903915, 121.07112  ,  44.988888 ,
#         12.541223 ,  52.181854 ,  56.635925 ,  44.308975 ,  11.905537 ,
#         10.081286 ,  51.681866 ,  29.622002 ,  21.664408 , 124.10499  ,
#         28.41634  ,   8.021911 ,  34.096283 ,  16.476034 ,   6.510211 ,
#         22.230251 ,  57.342865 ,  13.288539 ,  91.17021  ,   9.330199 ,
#         71.015724 ,  46.18714  ], dtype=float32)

# %%
y_test
# Out:
# 651      9.0
# 42      33.0
# 234      6.0
# 221     93.0
# 260      6.0
#        ...
# 271     11.0
# 396    120.0
# 609      2.0
# 252     58.0
# 235     73.0
# Name: case_n_18plus, Length: 237, dtype: float64

# %%
mae = mean_absolute_error(y_test, y_pred)



mae


print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Absolute Error: 15.174339695821834

# %%
plt.scatter(y_test, y_pred)


plt.xlabel("Test values")


plt.ylabel("Predicted values")
# Out:
# Text(0, 0.5, 'Predicted values')

# %% [markdown]
# ## Feature importance
#
#
#
# Feature importance is based on the number of times a feature is used in a split

# %%
# Assuming poisson_xgb is your pipeline and is already trained



# Access the XGBRegressor model from the pipeline using 'named_steps'


# Access the trained model


regressor_model = poisson_xgb.named_steps['regressor']



# Set feature names (necessary if X is a DataFrame)



regressor_model.get_booster().feature_names = list(X.columns)




# Plot importance



xgb.plot_importance(regressor_model, importance_type="weight")



plt.show()




# Extract importance as a DataFrame



importance_df = pd.DataFrame(
    
    
    regressor_model.get_booster().get_score(importance_type="weight").items(),
    
    
    
    
    columns=["Feature", "Importance"]
    
    
    
)



print(importance_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[91], line 19
#      11 regressor_model = poisson_xgb.named_steps['regressor']
#      15 # Set feature names (necessary if X is a DataFrame)
# ---> 19 regressor_model.get_booster().feature_names = list(X.columns)
#      24 # Plot importance
#      28 xgb.plot_importance(regressor_model, importance_type="weight")
#
# NameError: name 'X' is not defined

# %% [markdown]
# ## Gradient Boosting Regression Trees for Poisson regression

# %% [markdown]
# A non-linear model, namely Gradient Boosting Regression Trees
#
#
# Gradient Boosting also gives the possibility to fit the trees with a Poisson loss
#
#
# It uses an implicit log-link function instead of the default least-squares loss
#
#
#
# Here we only fit trees with the Poisson loss

# %%
poisson_gbrt = Pipeline([("preprocessor", Feature_preprocessing),
                        
                        
                        
    ("regressor", HistGradientBoostingRegressor(loss="poisson"))])

# %% [markdown]
# Let’s evalute the performance of  the model with  3 different regression metrics

# %%
def scoreEstimator(estimator, x_test,  y_test):
    
    
    
    """Score an estimator on the test set"""
    
    
    
    y_pred = estimator.predict(x_test)
    
    

    print("MSE: %.3f" %
          
          
          mean_squared_error(y_test, y_pred))
    
    
    print("MAE: %.3f" %
          
          
          mean_absolute_error(y_test, y_pred))
    
    

    # Ignore non-positive predictions, as they are invalid for
    
    
    # the Poisson deviance
    
    
    mask = y_pred > 0
    
    
    
    if (~mask).any():
        
        
        n_masked, n_samples = (~mask).sum(), mask.shape[0]
        
        
        
        print(f"WARNING: Estimator yields invalid, non-positive predictions "
              f" for {n_masked} samples out of {n_samples}. These predictions "
              f"are ignored when computing the Poisson deviance.")
        
        

    print("mean Poisson deviance: %.3f" %
          
          
          mean_poisson_deviance(y_test[mask],
                                
                                
                                y_pred[mask]))

# %%
x_train
# Out:
#      Pct_Civilian_Unemployed  Pct_BelowPoverty_18andOver  \
# 670                      5.6                   28.135629
# 623                      0.0                    8.541973
# 27                       3.0                    2.527292
# 152                      7.1                    8.501027
# 307                      0.0                    2.526003
# ..                       ...                         ...
# 76                       2.8                    3.944914
# 113                      4.3                   10.004407
# 301                      6.2                   13.123561
# 502                      9.2                   19.763153
# 109                      4.1                    4.392685
#
#      Pct_Population_Male_65andOver  Pct_Population_Female_65andOver  \
# 670                       7.637306                         9.031088
# 623                      14.138439                        10.898380
# 27                        8.439154                        10.954978
# 152                      12.689938                        11.457906
# 307                      24.665676                        20.802377
# ..                             ...                              ...
# 76                        7.675848                         9.360255
# 113                       9.946424                         8.455625
# 301                       7.674597                        10.897928
# 502                       6.480674                        10.045529
# 109                       7.478736                         9.510379
#
#      Pct_Black_65andOver  Pct_Black_Male_65andOver  \
# 670             1.150259                  0.575130
# 623             0.000000                  0.000000
# 27              1.281796                  0.569245
# 152             5.174538                  2.505133
# 307             0.000000                  0.000000
# ..                   ...                       ...
# 76              0.592560                  0.230440
# 113             6.778477                  4.122991
# 301             0.383730                  0.153492
# 502             7.739998                  2.518648
# 109             1.031246                  0.546472
#
#      Pct_Black_Female_65andOver  Pct_White_65andOver  \
# 670                    0.575130            15.409326
# 623                    0.000000            25.036819
# 27                     0.712551            14.943673
# 152                    2.669405            18.973306
# 307                    0.000000            41.753343
# ..                          ...                  ...
# 76                     0.362120            13.557555
# 113                    2.655486            11.320755
# 301                    0.230238            16.577130
# 502                    5.221350             8.166231
# 109                    0.484774            15.433432
#
#      Pct_White_Male_65andOver  Pct_White_Female_65andOver  ...  \
# 670                  6.968912                    8.440415  ...
# 623                 14.138439                   10.898380  ...
# 27                   6.544325                    8.399347  ...
# 152                 10.184805                    8.788501  ...
# 307                 24.665676                   17.087667  ...
# ..                        ...                         ...  ...
# 76                   6.457808                    7.099748  ...
# 113                  5.730259                    5.590496  ...
# 301                  7.521105                    9.056025  ...
# 502                  3.903904                    4.262327  ...
# 109                  6.729540                    8.703891  ...
#
#      OBESITY_CrudePrev  Median_Household_Income  ZCTA_pm2_5  sdi_score  \
# 670               30.6                  48411.0    7.508014       59.0
# 623               30.6                  72563.0    7.392398       17.0
# 27                31.0                 131184.0    7.833080        2.0
# 152               33.3                  44115.0    7.504450       38.0
# 307               29.8                  58261.0    7.120594        4.0
# ..                 ...                      ...         ...        ...
# 76                20.7                 147324.0    8.414932       12.0
# 113               38.0                  53240.0    7.642221       48.0
# 301               37.4                  70268.0    7.497583       70.0
# 502               37.5                  48353.0    7.322830       83.0
# 109               30.5                  93389.0    7.845270       13.0
#
#      Pct_White_Male_Between18and65  Pct_White_Female_Between18and65  \
# 670                      37.580311                        38.015544
# 623                      40.206186                        27.540501
# 27                       27.427252                        26.834123
# 152                      24.845996                        31.909651
# 307                      22.288262                        21.545319
# ..                             ...                              ...
# 76                       29.929771                        28.953144
# 113                      36.384812                        13.929653
# 301                      24.558711                        26.784344
# 502                      16.681197                        19.907004
# 109                      32.691375                        32.669340
#
#      Pct_Black_Female_Between18and65  Pct_Black_Male_Between18and65  \
# 670                         3.207254                       1.575130
# 623                         0.000000                       0.000000
# 27                          5.815851                       4.553959
# 152                         5.420945                      11.334702
# 307                         9.361070                       0.000000
# ..                               ...                            ...
# 76                          1.338747                       1.223527
# 113                         9.154437                      16.142558
# 301                        18.035303                      10.130468
# 502                        21.263199                      19.897317
# 109                         6.394606                       5.729144
#
#      Pct_Hisp_Male_Between18and65  Pct_Hisp_Female_Between18and65
# 670                      0.642487                        0.554404
# 623                      0.000000                        0.000000
# 27                       4.557940                        4.868437
# 152                      1.765914                        0.739220
# 307                      0.000000                        0.000000
# ..                            ...                             ...
# 76                       3.791287                        3.588280
# 113                      9.364081                        1.374330
# 301                      1.227936                        0.153492
# 502                      2.557396                        3.293616
# 109                      1.304482                        2.551672
#
# [551 rows x 25 columns]

# %%
y_train
# Out:
# 670    74.0
# 623     7.0
# 27     72.0
# 152    17.0
# 307     5.0
#        ...
# 76     40.0
# 113    26.0
# 301     9.0
# 502    54.0
# 109    97.0
# Name: case_n_18plus, Length: 551, dtype: float64

# %%
poisson_gbrt.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('PercentToDecimal',
#                                                   Pipeline(steps=[('functiontransformer',
#                                                                    FunctionTransformer(func=<function <lambda> at 0x1533c1080>,
#                                                                                        validate=True))]),
#                                                   ['Pct_Civilian_Unemployed',
#                                                    'Pct_BelowPoverty_18andOver',
#                                                    'Pct_Population_Male_65andOver',
#                                                    'Pct_Population_Female_65andOver',
#                                                    'Pct_Black_65andOver',
#                                                    'Pct_Bla...
#                                                    'Pct_Black_Male_Between18and65',
#                                                    'Pct_Hisp_Male_Between18and65',
#                                                    'Pct_Hisp_Female_Between18and65']),
#                                                  ('StandardScaleTransformer',
#                                                   Pipeline(steps=[('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['BINGE_CrudePrev',
#                                                    'CSMOKING_CrudePrev',
#                                                    'OBESITY_CrudePrev',
#                                                    'Median_Household_Income',
#                                                    'ZCTA_pm2_5',
#                                                    'sdi_score'])])),
#                 ('regressor', HistGradientBoostingRegressor(loss='poisson'))])

# %%
print("Poisson Gradient Boosted Trees evaluation:")



scoreEstimator(poisson_gbrt, x_test,  y_test)
# Out:
# Poisson Gradient Boosted Trees evaluation:
# MSE: 648.868
# MAE: 15.769
# mean Poisson deviance: 12.264

# %% [markdown]
# Histogram of observed target values with that of predicted values

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 6), sharey = True)


fig.subplots_adjust(bottom=0.2)


n_bins = 20


for row_idx, df, label in zip(range(2),[x_train, y_test], ["train", "test"]):
    
    
    
    y.hist(bins=np.linspace(-1, 30, n_bins),ax = axes[row_idx])
    
    

    axes[row_idx].set_title("Data")
    
    
    
    axes[row_idx].set_yscale('log')
    
    

    axes[row_idx].set_xlabel("y-observed")
    
    
    
    axes[row_idx].set_ylim([1e1, 5e5])
    
    
    axes[row_idx].set_ylabel("Frequency")
    
    
    
    for idx, model in enumerate([poisson_gbrt]):
        
        
        
        if label != "test":
            
            y_pred = model.predict(df)
        
        
        
        pd.Series(y_pred).hist(bins=np.linspace(-1, 4, n_bins), color = 'k', ax = axes[idx+1])
        
        
        
        axes[idx+1].set(title = model[-1].__class__.__name__, yscale = 'log', xlabel = "y_pred + y_train")
        
        
        
plt.tight_layout()

# %%
poissoncustom_xgb = Pipeline([("preprocessor", Feature_preprocessing),
                        
                        
                        
    ("regressor", XGBRegressor(objective="count:poisson", max_depth = 6, learning_rate = 0.1, n_estimators=100))])

# %%
poissoncustom_xgb
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('PercentToDecimal',
#                                                   Pipeline(steps=[('functiontransformer',
#                                                                    FunctionTransformer(func=<function <lambda> at 0x317205ee0>,
#                                                                                        validate=True))]),
#                                                   ['Pct_Civilian_Unemployed',
#                                                    'Pct_BelowPoverty_18andOver',
#                                                    'Pct_Population_Male_65andOver',
#                                                    'Pct_Population_Female_65andOver',
#                                                    'Pct_Black_65andOver',
#                                                    'Pct_Bla...
#                               feature_types=None, feature_weights=None,
#                               gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=0.1,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=6, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=100, n_jobs=None,
#                               num_parallel_tree=None, ...))])

# %% [markdown]
# ## XGBoost Poisson Regression: Mathematical Formulation
#
#
# Let $Y_{i}$ denote the observed count over region $A_{i}$ with rate $\lambda_{i}$. In our case, $A_{i}$ refers to the total population. We assume:
#
# \begin{align}
#  Y_{i} \sim Poisson(A_{i}\lambda_{i})
# \end{align}
#
#
# The Poisson probability mass function is given by:
# \begin{align}
#  P(Y_{i} = y_{i}) = \frac{e^{-A_{i}\lambda_{i}} (A_{i}\lambda_{i})^{y_{i}}}{y_{i}!}
# \end{align}
# We model the rate $\lambda_{i}$ using tree at $t$ - iteration:
#
# \begin{align}
# \log(\lambda_{i}) = f(\mathbf{x}_{i}, \beta_{t})
# \end{align}
#
# The log-likelihood function for N observations is:
#
# \begin{align}
# \ell(\boldsymbol\lambda\mid \mathbf{y}, \mathbf{x}) = \sum_{i = 1}^{n}{(y_{i} \log(A_{i}\lambda_{i}) -  A_{i}\lambda_{i} - \log(y_{i}!))}
# \end{align}
#
#
# Substituting $\lambda_{i} = e^{f(\mathbf{x}_{i}, \;\beta_{t})}$ and ignoring constants, we have:
# \begin{align}
# \ell(\boldsymbol\lambda\mid \mathbf{y}, \mathbf{x}, \beta_{t}) &= \sum_{i = 1}^{n}{(y_{i} \log(A_{i}\lambda_{i}) -  A_{i}\lambda_{i} - \log(y_{i}!))}\\
# &\approx \sum_{i = 1}^{n}{(y_{i} \log(A_{i}\lambda_{i}) -  A_{i}\lambda_{i} - \log(y_{i}!))}\\
# &\approx \sum_{i = 1}^{n}{(y_{i} f(\mathbf{x}_{i},\; \beta_{t}) -  A_{i}e^{f(\mathbf{x}_{i}, \;\beta_{t})}})
# \end{align}
#
# In XGBoost Poisson Loss function, we minimize the objective function given by
#
# \begin{align}
# L(\boldsymbol\lambda\mid \mathbf{y}, \mathbf{x}, \beta_{t}) = -\ell(\boldsymbol\lambda\mid \mathbf{y}, \mathbf{x}, \beta_{t})
# \end{align}
# That is,
#
# \begin{align}
# L(\boldsymbol\lambda\mid \mathbf{y}, \mathbf{x}, \beta_{t}) =  \sum_{i = 1}^{n}{(A_{i}e^{f(\mathbf{x}_{i}, \;\beta_{t})}}- y_{i} f(\mathbf{x}_{i},\; \beta_{t}))
# \end{align}
#
# Next, we derive gradients:
#
# Gradient:
#
# \begin{align}
# \frac{dL}{df(\mathbf{x}_{i},\; \beta_{t})} = \sum_{i = 1}^{n}{(A_{i}e^{f(\mathbf{x}_{i}, \;\beta_{t})}}- y_{i})
# \end{align}
#
#
# Hessian:
#
# \begin{align}
# \frac{d^{2}L}{df(\mathbf{x}_{i},\; \beta_{t})^{2}} = \sum_{i = 1}^{n}{A_{i}e^{f(\mathbf{x}_{i}, \;\beta_{t})}}
# \end{align}
#
#
# These are used in XGBoost’s custom objective function for efficient optimization

# %% [markdown]
# ## Poisson Deviance
#
#
# The deviance compares the fitted model to the saturated model
#
# \begin{align}
# D = 2 (\ell(\text{saturated}) - \ell(\hat{\lambda}))
# \end{align}
#
#
# * Log-Likelihood of the Fitted Model
#
#
# \begin{align}
# \ell(\hat{\lambda}) = \sum_{i=1}^{n} \left(y_i \log(A_i \hat{\lambda_i}) - A_i \hat{\lambda_i} - \log(y_i!) \right)
# \end{align}
#
# * Step 2: Log-Likelihood of the Saturated Model
#
#
# \begin{align}
# \ell(\text{saturated}) = \sum_{i=1}^{n} \left( y_i \log(y_i) - y_i - \log(y_i!) \right)
# \end{align}
#
# * Step 3: Deviance Calculation
# Substitute the log-likelihoods into the deviance expression:
# \begin{align}
# D = 2 \sum_{i=1}^{n} \left( y_i \log\left(\frac{y_i}{A_i \hat{\lambda_i}}\right) - (y_i - A_i \hat{\lambda_i}) \right)
# \end{align}
#
# * Step 4: Final Poisson Deviance Formula Using $ A_{i} \lambda_i$
#
# \begin{align}
# D = 2 \sum_{i=1}^{n} \left( y_i \log\left(\frac{y_i}{A_i \hat{\lambda_i}}\right) - (y_i - A_i \hat{\lambda_i}) \right)
# \end{align}
#
# * Interpretation
#
#
# This formulation penalizes deviations from observed values based on the predicted rate per area or population unit
#
#
# It effectively handles cases where rates vary by region or population.

# %%
xtrain = x_train.copy(deep = True)


xtest = x_test.copy(deep = True)

# %%
xtrain.head()
# Out:
#      Pct_Civilian_Unemployed  Pct_BelowPoverty_18andOver  \
# 670                      5.6                   28.135629
# 623                      0.0                    8.541973
# 27                       3.0                    2.527292
# 152                      7.1                    8.501027
# 307                      0.0                    2.526003
#
#      Pct_Population_Male_65andOver  Pct_Population_Female_65andOver  \
# 670                       7.637306                         9.031088
# 623                      14.138439                        10.898380
# 27                        8.439154                        10.954978
# 152                      12.689938                        11.457906
# 307                      24.665676                        20.802377
#
#      Pct_Black_65andOver  Pct_Black_Male_65andOver  \
# 670             1.150259                  0.575130
# 623             0.000000                  0.000000
# 27              1.281796                  0.569245
# 152             5.174538                  2.505133
# 307             0.000000                  0.000000
#
#      Pct_Black_Female_65andOver  Pct_White_65andOver  \
# 670                    0.575130            15.409326
# 623                    0.000000            25.036819
# 27                     0.712551            14.943673
# 152                    2.669405            18.973306
# 307                    0.000000            41.753343
#
#      Pct_White_Male_65andOver  Pct_White_Female_65andOver  ...  \
# 670                  6.968912                    8.440415  ...
# 623                 14.138439                   10.898380  ...
# 27                   6.544325                    8.399347  ...
# 152                 10.184805                    8.788501  ...
# 307                 24.665676                   17.087667  ...
#
#      OBESITY_CrudePrev  Median_Household_Income  ZCTA_pm2_5  sdi_score  \
# 670               30.6                  48411.0    7.508014       59.0
# 623               30.6                  72563.0    7.392398       17.0
# 27                31.0                 131184.0    7.833080        2.0
# 152               33.3                  44115.0    7.504450       38.0
# 307               29.8                  58261.0    7.120594        4.0
#
#      Pct_White_Male_Between18and65  Pct_White_Female_Between18and65  \
# 670                      37.580311                        38.015544
# 623                      40.206186                        27.540501
# 27                       27.427252                        26.834123
# 152                      24.845996                        31.909651
# 307                      22.288262                        21.545319
#
#      Pct_Black_Female_Between18and65  Pct_Black_Male_Between18and65  \
# 670                         3.207254                       1.575130
# 623                         0.000000                       0.000000
# 27                          5.815851                       4.553959
# 152                         5.420945                      11.334702
# 307                         9.361070                       0.000000
#
#      Pct_Hisp_Male_Between18and65  Pct_Hisp_Female_Between18and65
# 670                      0.642487                        0.554404
# 623                      0.000000                        0.000000
# 27                       4.557940                        4.868437
# 152                      1.765914                        0.739220
# 307                      0.000000                        0.000000
#
# [5 rows x 25 columns]

# %%
xtest.head()
# Out:
#      Pct_Civilian_Unemployed  Pct_BelowPoverty_18andOver  \
# 651                      5.4                    9.920635
# 42                       2.6                    9.323803
# 234                      3.3                    5.862458
# 221                      3.8                   15.130193
# 260                      2.7                   10.481414
#
#      Pct_Population_Male_65andOver  Pct_Population_Female_65andOver  \
# 651                      17.619048                        16.428571
# 42                        8.056185                        10.833963
# 234                       8.117249                        10.372041
# 221                       7.659630                        10.091465
# 260                      12.065814                        10.725168
#
#      Pct_Black_65andOver  Pct_Black_Male_65andOver  \
# 651             0.000000                  0.000000
# 42              0.730663                  0.327538
# 234             0.000000                  0.000000
# 221             0.866964                  0.377129
# 260            14.929921                  7.434491
#
#      Pct_Black_Female_65andOver  Pct_White_65andOver  \
# 651                    0.000000            34.047619
# 42                     0.403124            15.847821
# 234                    0.000000            18.489290
# 221                    0.489835            16.641380
# 260                    7.495430             7.861060
#
#      Pct_White_Male_65andOver  Pct_White_Female_65andOver  ...  \
# 651                 17.619048                   16.428571  ...
# 42                   6.689342                    9.158478  ...
# 234                  8.117249                   10.372041  ...
# 221                  7.135116                    9.506264  ...
# 260                  4.631322                    3.229738  ...
#
#      OBESITY_CrudePrev  Median_Household_Income  ZCTA_pm2_5  sdi_score  \
# 651               36.2                  34914.0    7.479898       33.0
# 42                22.8                 106929.0    8.324991       40.0
# 234               34.2                  72328.0    7.159498        6.0
# 221               32.2                  47684.0    7.182274       76.0
# 260               35.5                  51618.0    7.301255       43.0
#
#      Pct_White_Male_Between18and65  Pct_White_Female_Between18and65  \
# 651                      31.984127                        33.809524
# 42                       29.232804                        29.617032
# 234                      39.571590                        41.939121
# 221                      32.454809                        35.441502
# 260                      20.962828                        21.633151
#
#      Pct_Black_Female_Between18and65  Pct_Black_Male_Between18and65  \
# 651                         0.000000                       0.000000
# 42                          4.213908                       4.106828
# 234                         0.000000                       0.000000
# 221                         2.800295                       3.138411
# 260                        19.987812                      14.137721
#
#      Pct_Hisp_Male_Between18and65  Pct_Hisp_Female_Between18and65
# 651                      0.000000                        0.000000
# 42                       5.120937                        4.976064
# 234                      0.000000                        0.000000
# 221                      8.947072                        8.409554
# 260                      3.046923                        1.340646
#
# [5 rows x 25 columns]

# %%
Percent2DecimalTransformer = make_pipeline(FunctionTransformer(lambda X: X / 100, validate = True))



StandardScaleTransformer = make_pipeline(StandardScaler())



Feature_preprocessing = ColumnTransformer([
    
    
    
    
        ("PercentToDecimal", Percent2DecimalTransformer, ["Pct_Civilian_Unemployed", 
                            "Pct_BelowPoverty_18andOver",
                            "Pct_Population_Male_65andOver", "Pct_Population_Female_65andOver",
                            "Pct_Black_65andOver","Pct_Black_Male_65andOver", 'Pct_Black_Female_65andOver',
                            "Pct_White_65andOver","Pct_White_Male_65andOver", "Pct_White_Female_65andOver",
                            "Pct_Hisp_65andOver", "Pct_Hisp_Male_65andOver", "Pct_Hisp_Female_65andOver",
                            "Pct_White_Male_Between18and65", "Pct_White_Female_Between18and65",
                            "Pct_Black_Female_Between18and65", "Pct_Black_Male_Between18and65",
                            "Pct_Hisp_Male_Between18and65", "Pct_Hisp_Female_Between18and65"]),
        
    
    
        ("StandardScaleTransformer",StandardScaleTransformer, ["BINGE_CrudePrev", "CSMOKING_CrudePrev", 
                                                       
                                                       "OBESITY_CrudePrev",
                                                       "Median_Household_Income", "ZCTA_pm2_5", "sdi_score"])])

# %%
# Manually apply Percent2DecimalTransformer


percent_columns = ["Pct_Civilian_Unemployed", "Pct_BelowPoverty_18andOver",
    
    
    "Pct_Population_Male_65andOver", "Pct_Population_Female_65andOver",
                   
                   
    "Pct_Black_65andOver", "Pct_Black_Male_65andOver", "Pct_Black_Female_65andOver",
                   
                   
                   
    "Pct_White_65andOver", "Pct_White_Male_65andOver", "Pct_White_Female_65andOver",
                   
                   
                   
    "Pct_Hisp_65andOver", "Pct_Hisp_Male_65andOver", "Pct_Hisp_Female_65andOver",
                   
                   
    "Pct_White_Male_Between18and65", "Pct_White_Female_Between18and65",
                   
                   
                   
    "Pct_Black_Female_Between18and65", "Pct_Black_Male_Between18and65",
                   
                   
                   
    "Pct_Hisp_Male_Between18and65", "Pct_Hisp_Female_Between18and65"
                   
                   
]


xtrain[percent_columns] = xtrain[percent_columns] / 100





# Manually apply StandardScaleTransformer



scale_columns = ["BINGE_CrudePrev", 
                 
                 
                 "CSMOKING_CrudePrev", 
                 
                 
                 
                 "OBESITY_CrudePrev",
                 
                 
                 
                 "Median_Household_Income", 
                 
                 
                 
                 "ZCTA_pm2_5", 
                 
                 
                 
                 "sdi_score"]



scaler = StandardScaler()


# Fit and transform the training data


xtrain[scale_columns] = scaler.fit_transform(xtrain[scale_columns])



# Apply the same transformation to the test data (using the learned parameters)


xtest[scale_columns] = scaler.transform(xtest[scale_columns])




xtest[percent_columns] = xtest[percent_columns] / 100

# %%
xtrain.head()
# Out:
#      Pct_Civilian_Unemployed  Pct_BelowPoverty_18andOver  \
# 670                    0.056                    0.281356
# 623                    0.000                    0.085420
# 27                     0.030                    0.025273
# 152                    0.071                    0.085010
# 307                    0.000                    0.025260
#
#      Pct_Population_Male_65andOver  Pct_Population_Female_65andOver  \
# 670                       0.076373                         0.090311
# 623                       0.141384                         0.108984
# 27                        0.084392                         0.109550
# 152                       0.126899                         0.114579
# 307                       0.246657                         0.208024
#
#      Pct_Black_65andOver  Pct_Black_Male_65andOver  \
# 670             0.011503                  0.005751
# 623             0.000000                  0.000000
# 27              0.012818                  0.005692
# 152             0.051745                  0.025051
# 307             0.000000                  0.000000
#
#      Pct_Black_Female_65andOver  Pct_White_65andOver  \
# 670                    0.005751             0.154093
# 623                    0.000000             0.250368
# 27                     0.007126             0.149437
# 152                    0.026694             0.189733
# 307                    0.000000             0.417533
#
#      Pct_White_Male_65andOver  Pct_White_Female_65andOver  ...  \
# 670                  0.069689                    0.084404  ...
# 623                  0.141384                    0.108984  ...
# 27                   0.065443                    0.083993  ...
# 152                  0.101848                    0.087885  ...
# 307                  0.246657                    0.170877  ...
#
#      OBESITY_CrudePrev  Median_Household_Income  ZCTA_pm2_5  sdi_score  \
# 670          -0.696928                -0.510399   -0.197608   0.809299
# 623          -0.696928                 0.270782   -0.446034  -0.914950
# 27           -0.614879                 2.166840    0.500861  -1.530753
# 152          -0.143101                -0.649351   -0.205267  -0.052826
# 307          -0.861025                -0.191807   -1.030060  -1.448646
#
#      Pct_White_Male_Between18and65  Pct_White_Female_Between18and65  \
# 670                       0.375803                         0.380155
# 623                       0.402062                         0.275405
# 27                        0.274273                         0.268341
# 152                       0.248460                         0.319097
# 307                       0.222883                         0.215453
#
#      Pct_Black_Female_Between18and65  Pct_Black_Male_Between18and65  \
# 670                         0.032073                       0.015751
# 623                         0.000000                       0.000000
# 27                          0.058159                       0.045540
# 152                         0.054209                       0.113347
# 307                         0.093611                       0.000000
#
#      Pct_Hisp_Male_Between18and65  Pct_Hisp_Female_Between18and65
# 670                      0.006425                        0.005544
# 623                      0.000000                        0.000000
# 27                       0.045579                        0.048684
# 152                      0.017659                        0.007392
# 307                      0.000000                        0.000000
#
# [5 rows x 25 columns]

# %%
xtest.head()
# Out:
#      Pct_Civilian_Unemployed  Pct_BelowPoverty_18andOver  \
# 651                    0.054                    0.099206
# 42                     0.026                    0.093238
# 234                    0.033                    0.058625
# 221                    0.038                    0.151302
# 260                    0.027                    0.104814
#
#      Pct_Population_Male_65andOver  Pct_Population_Female_65andOver  \
# 651                       0.176190                         0.164286
# 42                        0.080562                         0.108340
# 234                       0.081172                         0.103720
# 221                       0.076596                         0.100915
# 260                       0.120658                         0.107252
#
#      Pct_Black_65andOver  Pct_Black_Male_65andOver  \
# 651             0.000000                  0.000000
# 42              0.007307                  0.003275
# 234             0.000000                  0.000000
# 221             0.008670                  0.003771
# 260             0.149299                  0.074345
#
#      Pct_Black_Female_65andOver  Pct_White_65andOver  \
# 651                    0.000000             0.340476
# 42                     0.004031             0.158478
# 234                    0.000000             0.184893
# 221                    0.004898             0.166414
# 260                    0.074954             0.078611
#
#      Pct_White_Male_65andOver  Pct_White_Female_65andOver  ...  \
# 651                  0.176190                    0.164286  ...
# 42                   0.066893                    0.091585  ...
# 234                  0.081172                    0.103720  ...
# 221                  0.071351                    0.095063  ...
# 260                  0.046313                    0.032297  ...
#
#      OBESITY_CrudePrev  Median_Household_Income  ZCTA_pm2_5  sdi_score  \
# 651           0.451750                -0.946951   -0.258023  -0.258093
# 42           -2.296872                 1.382328    1.557832   0.029281
# 234           0.041508                 0.263181   -0.946466  -1.366539
# 221          -0.368734                -0.533914   -0.897528   1.507209
# 260           0.308166                -0.406671   -0.641872   0.152442
#
#      Pct_White_Male_Between18and65  Pct_White_Female_Between18and65  \
# 651                       0.319841                         0.338095
# 42                        0.292328                         0.296170
# 234                       0.395716                         0.419391
# 221                       0.324548                         0.354415
# 260                       0.209628                         0.216332
#
#      Pct_Black_Female_Between18and65  Pct_Black_Male_Between18and65  \
# 651                         0.000000                       0.000000
# 42                          0.042139                       0.041068
# 234                         0.000000                       0.000000
# 221                         0.028003                       0.031384
# 260                         0.199878                       0.141377
#
#      Pct_Hisp_Male_Between18and65  Pct_Hisp_Female_Between18and65
# 651                      0.000000                        0.000000
# 42                       0.051209                        0.049761
# 234                      0.000000                        0.000000
# 221                      0.089471                        0.084096
# 260                      0.030469                        0.013406
#
# [5 rows x 25 columns]

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /Users/zhuoranwang/anaconda3/lib/python3.12/site-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in /Users/zhuoranwang/anaconda3/lib/python3.12/site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /Users/zhuoranwang/anaconda3/lib/python3.12/site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /Users/zhuoranwang/anaconda3/lib/python3.12/site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in /Users/zhuoranwang/anaconda3/lib/python3.12/site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /Users/zhuoranwang/anaconda3/lib/python3.12/site-packages (from statsmodels) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/zhuoranwang/anaconda3/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/zhuoranwang/anaconda3/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/zhuoranwang/anaconda3/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3)
# Requirement already satisfied: six in /Users/zhuoranwang/anaconda3/lib/python3.12/site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
X = xtrain



ytrain = ytrain



weight = N_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[146], line 5
#       1 X = xtrain
# ----> 5 ytrain = ytrain
#       9 weight = N_train
#
# NameError: name 'ytrain' is not defined

# %% [markdown]
# Let:
#
# - \( y_i \): observed count
# - \( \eta_i \): predicted log-rate (i.e., `preds`)
# - \( \hat{\lambda}_i = \exp(\eta_i) \): predicted Poisson rate
# - \( A_i \): exposure (e.g., population or time)
#
# The **Poisson deviance** is defined as:
#
# $$
# D_{\text{Poisson}} = 2 \sum_{i=1}^{n} \left[
# y_i \log \left( \frac{y_i}{\hat{\lambda}_i A_i} \right) - (y_i - \hat{\lambda}_i A_i)
# \right]
# $$
#
# with the convention that:
#
# $$
# y_i \log \left( \frac{y_i}{\hat{\lambda}_i A_i} \right) = 0 \quad \text{if } y_i = 0
# $$
#
# The **L2 regularization** term is:
#
# $$
# \text{Reg}_{\ell_2} = \lambda \sum_{i=1}^{n} \eta_i^2
# $$
#
# So the **total loss** becomes:
#
# $$
# \text{Loss} = D_{\text{Poisson}} + \text{Reg}_{\ell_2}
# $$

# %%
ytrain = ytrain



X = xtrain



weight = N_train



# Custom objective for Poisson regression



# Ensures the model optimizes for Poisson regression



def poisson_objective(preds, dtrain):
    y_true = dtrain.get_label()
    A_i = dtrain.get_float_info('weight')  
    preds = np.exp(preds)
    grad = A_i * preds - y_true
    hess = A_i * preds
    return grad, hess


#  checks performance using the Poisson deviance

def poisson_deviance(preds, dtrain, reg_lambda=0.0):
    
    
    y_true = dtrain.get_label()
    
    
    A_i = dtrain.get_float_info('weight')  

    rate_pred = np.exp(preds)

    # Poisson deviance
    with np.errstate(divide='ignore', invalid='ignore'):
        term1 = np.where(y_true > 0, y_true * np.log(y_true / (rate_pred * A_i)), 0.0)
        term2 = y_true - rate_pred * A_i
        deviance = 2 * np.sum(term1 - term2)

    # L2 regularization on predicted log-rates (not on exp(preds))
    reg_term = reg_lambda * np.sum(preds ** 2)

    return 'poisson_deviance_reg', deviance + reg_term
    
    
    # preds = np.exp(preds)
    
    
    # deviance = 2 * np.sum(y_true * np.log((y_true) / (preds* A_i)) - (y_true - preds* A_i))
    
    
    # return 'poisson_deviance', deviance


def make_poisson_feval(reg_lambda=0.0):
    return lambda preds, dtrain: poisson_deviance(preds, dtrain, reg_lambda=reg_lambda)


dtrain = xgb.DMatrix(X, label = ytrain, weight = weight)



params = {
    
    
    'objective': 'reg:squarederror', 
    
    
    'eval_metric': 'rmse', 
    
    
}

model = xgb.train(
    params,
    dtrain,
    num_boost_round=100,
    obj=poisson_objective,
    feval=make_poisson_deviance(reg_lambda=1.0),  # or 0.0 if no regularization
    evals=[(dtrain, 'train')],
    verbose_eval=True
)



# model = xgb.train(
    
    
#     params,
    
    
#     dtrain,
    
    
#     num_boost_round = 100,
    
    
    
#     obj = poisson_objective,
    
    
    
#     custom_metric = poisson_deviance)



preds = model.predict(dtest)



poisson_preds = N_test*np.exp(preds)




mae = np.sqrt(mean_squared_error(y_test, poisson_preds))



print(f"MAE: {mae}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 ytrain = ytrain
#       5 X = xtrain
#       9 weight = N_train
#
# NameError: name 'ytrain' is not defined

# %%
dtrain = xgb.DMatrix(X, label = ytrain, weight = weight)



print(dtrain.num_row())



print(dtrain.num_col())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 dtrain = xgb.DMatrix(X, label = ytrain, weight = weight)
#       5 print(dtrain.num_row())
#       9 print(dtrain.num_col())
#
# NameError: name 'ytrain' is not defined

# %%
X = xtest


dtest = xgb.DMatrix(X, label = y_test, weight = N_test)

# %%
poisson_preds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 poisson_preds
#
# NameError: name 'poisson_preds' is not defined

# %%
# Assuming 'model' is a Booster object trained by xgb.train



# Plot feature importance



xgb.plot_importance(model, importance_type="weight")




plt.show()



# Extract feature importance into a DataFrame



importance_df = pd.DataFrame(model.get_score(importance_type="weight").items(),
                             
                             
                             
    columns=["Feature", "Importance"]
                             
                             
                             
)



print(importance_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[136], line 9
#       1 # Assuming 'model' is a Booster object trained by xgb.train
#       2
#       3
#       4
#       5 # Plot feature importance
# ----> 9 xgb.plot_importance(model, importance_type="weight")
#      14 plt.show()
#      18 # Extract feature importance into a DataFrame
#
# File ~/anaconda3/lib/python3.12/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/xgboost/plotting.py:99, in plot_importance(booster, ax, height, xlim, ylim, title, xlabel, ylabel, fmap, importance_type, max_num_features, grid, show_values, values_format, **kwargs)
#      97     importance = booster
#      98 else:
# ---> 99     raise ValueError("tree must be Booster, XGBModel or dict instance")
#     101 if not importance:
#     102     raise ValueError(
#     103         "Booster.get_score() results in empty.  "
#     104         + "This maybe caused by having all trees as decision dumps."
#     105     )
#
# ValueError: tree must be Booster, XGBModel or dict instance
